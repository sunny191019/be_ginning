# %% [markdown]
# ## 18-9. 프로젝트 : 다양한 OCR모델 비교하기

# %%
import os
from os import listdir
from os.path import isfile, join

# keras
import matplotlib.pyplot as plt
import keras_ocr
import matplotlib.image as img
# %matplotlib inline

# tesseract
import os
import pytesseract
from PIL import Image
from pytesseract import Output
import matplotlib.pyplot as plt

# 다운받은 인증키 경로가 정확하게 지정되어 있어야 합니다. 
# !ls -l $GOOGLE_APPLICATION_CREDENTIALS

import os
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] =  os.getenv('HOME')+'/aiffel/ocr_python/my_google_api_key.json'
# Out:
# -rw-rw-rw- 1 ssac15 ssac15 2337  3월 15 16:27 /home/ssac15/aiffel/ocr_python/my_google_api_key.json

# %% [markdown]
# ### Step1. 검증용 데이터셋 준비
# ---
#
#
# #### 아래의 캐글에서 데이터 셋 가져 옴
# https://www.kaggle.com/harishml/ocrdataset

# %%
# 이미지 파일들의 리스트를 한 번에 얻는 코드
work_dir= os.getenv('HOME')+'/aiffel/ocr_python/images'
img_list = [join(work_dir,f) for f in listdir(work_dir) if isfile(join(work_dir, f))]

img_list.sort()
img_list
# Out:
# ['/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0001.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0002.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0003.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0004.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0005.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0006.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0007.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0008.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0009.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0010.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0011.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0012.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0013.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0014.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0015.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0016.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0017.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0018.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0019.jpeg',
#  '/home/ssac15/aiffel/ocr_python/images/FPDATA0401img0020.jpeg']

# %%
plt.figure(figsize=(15,15))
for idx, im in enumerate(img_list):
    plt.subplot(5,4, idx+1)
    im = img.imread(im)
    plt.imshow(im)

# %% [markdown]
# ### Step2. Google OCR API, keras-ocr, Tesseract로 테스트 진행
# ---
# 위 3가지 모듈을 활용하는 방법에 대해서는 코드 레벨로 이미 경험해 보셨을 것입니다. 이미지 리스트를 정리한 후 반복문을 실행하며 모듈이 출력한 결과를 모아 봅시다.

# %% [markdown]
# ## 1. GOOGLE API

# %%
def detect_text(path):
    """Detects text in the file."""
    from google.cloud import vision
    import io
    client = vision.ImageAnnotatorClient()

    with io.open(path, 'rb') as image_file:
        content = image_file.read()
        
    image = vision.Image(content=content)

    response = client.text_detection(image=image)
    texts = response.text_annotations
    print('Texts: in '+ path )

    for text in texts:
       print('\n"{}"'.format(text.description))

    vertices = (['({},{})'.format(vertex.x, vertex.y)
                 for vertex in text.bounding_poly.vertices])

    print('bounds: {}\n------------------다음 이미지 -------------------\n'.format(','.join(vertices)))

    if response.error.message:
        raise Exception(
            '{}\nFor more info on error messages, check: '
            'https://cloud.google.com/apis/design/errors'.format(
                response.error.message))

# %%
for img in img_list:
    detect_text(img)
# Out:
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0001.jpeg
#
# "00367635
# BCPP-335273 010176551683 ZDQ0537 / 62 $12,000.00 12.37%
# 6 months
# $12,742.20 $2,123.70
# No
# Mr
# PÁUL H WELLS
# 1451 GREEN RD
# ANN ARBOR
# MI
# 48105
# USA
# Mobile
# Divorced
# DUANÉ HOPLAND
# 1 years
# Manager
# Promo
# Ok
# 4175.00
# US DEPT OF LABOR OPÅ
# RIVER VÅLLEY CREDIT UNION
# "
#
# "00367635"
#
# "BCPP-335273"
#
# "010176551683"
#
# "ZDQ0537"
#
# "/"
#
# "62"
#
# "$12,000.00"
#
# "12.37%"
#
# "6"
#
# "months"
#
# "$12,742.20"
#
# "$2,123.70"
#
# "No"
#
# "Mr"
#
# "PÁUL"
#
# "H"
#
# "WELLS"
#
# "1451"
#
# "GREEN"
#
# "RD"
#
# "ANN"
#
# "ARBOR"
#
# "MI"
#
# "48105"
#
# "USA"
#
# "Mobile"
#
# "Divorced"
#
# "DUANÉ"
#
# "HOPLAND"
#
# "1"
#
# "years"
#
# "Manager"
#
# "Promo"
#
# "Ok"
#
# "4175.00"
#
# "US"
#
# "DEPT"
#
# "OF"
#
# "LABOR"
#
# "OPÅ"
#
# "RIVER"
#
# "VÅLLEY"
#
# "CREDIT"
#
# "UNION"
# bounds: (554,83),(589,83),(589,90),(554,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0002.jpeg
#
# "00367636
# IUWC-420152 105055276627 HKF3800 / 85 $26,000.00 11.69%
# 9 months
# $28,279.55 $3,142.17
# no
# Mr
# JOSHUA A MARTIN
# 2255 NORTH GEMINI DRIVE
# FLAGSTAFF
# AZ
# 86001
# United Statė
# Single
# 1 years
# Sr Áccountant
# Letter
# ALVINA LACKMAN
# Promo
# Ok
# 5999.00
# DOL ESA OWCP SE REGION
# ARIZONA HIGHER ED LOAN AUTHORITY
# "
#
# "00367636"
#
# "IUWC-420152"
#
# "105055276627"
#
# "HKF3800"
#
# "/"
#
# "85"
#
# "$26,000.00"
#
# "11.69%"
#
# "9"
#
# "months"
#
# "$28,279.55"
#
# "$3,142.17"
#
# "no"
#
# "Mr"
#
# "JOSHUA"
#
# "A"
#
# "MARTIN"
#
# "2255"
#
# "NORTH"
#
# "GEMINI"
#
# "DRIVE"
#
# "FLAGSTAFF"
#
# "AZ"
#
# "86001"
#
# "United"
#
# "Statė"
#
# "Single"
#
# "1"
#
# "years"
#
# "Sr"
#
# "Áccountant"
#
# "Letter"
#
# "ALVINA"
#
# "LACKMAN"
#
# "Promo"
#
# "Ok"
#
# "5999.00"
#
# "DOL"
#
# "ESA"
#
# "OWCP"
#
# "SE"
#
# "REGION"
#
# "ARIZONA"
#
# "HIGHER"
#
# "ED"
#
# "LOAN"
#
# "AUTHORITY"
# bounds: (565,83),(630,83),(630,90),(565,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0003.jpeg
#
# "00367637 QZCV-242354 827257048756 OPL1112 / 44
# $23,000.00 10.59%
# 24 months
# $27,871.40 $1,161.31
# No
# MR
# RICHARD W EDWARDS
# 810 BEAR TAVERN RD STE 206
# WEST TRENTON NJ
# 8628
# United State of America
# Móbile
# NA
# DENISE EVERHEART
# 13 years
# Legal Executive Distribution
# Ok
# 1961.00
# DOL OCFO
# SOUTH BERGEN FCU
# "
#
# "00367637"
#
# "QZCV-242354"
#
# "827257048756"
#
# "OPL1112"
#
# "/"
#
# "44"
#
# "$23,000.00"
#
# "10.59%"
#
# "24"
#
# "months"
#
# "$27,871.40"
#
# "$1,161.31"
#
# "No"
#
# "MR"
#
# "RICHARD"
#
# "W"
#
# "EDWARDS"
#
# "810"
#
# "BEAR"
#
# "TAVERN"
#
# "RD"
#
# "STE"
#
# "206"
#
# "WEST"
#
# "TRENTON"
#
# "NJ"
#
# "8628"
#
# "United"
#
# "State"
#
# "of"
#
# "America"
#
# "Móbile"
#
# "NA"
#
# "DENISE"
#
# "EVERHEART"
#
# "13"
#
# "years"
#
# "Legal"
#
# "Executive"
#
# "Distribution"
#
# "Ok"
#
# "1961.00"
#
# "DOL"
#
# "OCFO"
#
# "SOUTH"
#
# "BERGEN"
#
# "FCU"
# bounds: (511,83),(531,83),(531,90),(511,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0004.jpeg
#
# "00367638
# INBH-226814 801616186786 WUR1756/41 $37,000.00 12.48%
# 24 months
# $46,235.20 $1,926.47
# No
# RYAN E BEAÜLIN
# mr
# 1201 WEST UNIV AVENUE STE 100
# URBANA
# IL
# 61801
# USA
# Mobile
# Divorced
# JAY MCCORMACK
# 14 years
# Payróll Specialist Service
# Ok
# 3090.00
# OSHA BATON ROÜGE AREA
# BANK OF AMERICA, NA
# "
#
# "00367638"
#
# "INBH-226814"
#
# "801616186786"
#
# "WUR1756/41"
#
# "$37,000.00"
#
# "12.48%"
#
# "24"
#
# "months"
#
# "$46,235.20"
#
# "$1,926.47"
#
# "No"
#
# "RYAN"
#
# "E"
#
# "BEAÜLIN"
#
# "mr"
#
# "1201"
#
# "WEST"
#
# "UNIV"
#
# "AVENUE"
#
# "STE"
#
# "100"
#
# "URBANA"
#
# "IL"
#
# "61801"
#
# "USA"
#
# "Mobile"
#
# "Divorced"
#
# "JAY"
#
# "MCCORMACK"
#
# "14"
#
# "years"
#
# "Payróll"
#
# "Specialist"
#
# "Service"
#
# "Ok"
#
# "3090.00"
#
# "OSHA"
#
# "BATON"
#
# "ROÜGE"
#
# "AREA"
#
# "BANK"
#
# "OF"
#
# "AMERICA,"
#
# "NA"
# bounds: (540,82),(554,82),(554,90),(540,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0005.jpeg
#
# "00367639
# UCVP-716758 481552482024 TRĖ4343 / 00 $13,000.00 12.74%
# 15 months
# $15,070.25 $1,004.68
# NO
# Mr
# H. FRANKLIN PERCIVÁL
# 303 NATIONAL CENTÉR
# RĖSTON
# VA
# 20192
# US
# Letter
# Married
# BENNY CHEUK
# 6 years
# Legal Exécutive
# Tech
# Ok
# 1829.00
# US DOL/OSHA
# BONY MELLON ELT SMS TRÜST 1994-B
# "
#
# "00367639"
#
# "UCVP-716758"
#
# "481552482024"
#
# "TRĖ4343"
#
# "/"
#
# "00"
#
# "$13,000.00"
#
# "12.74%"
#
# "15"
#
# "months"
#
# "$15,070.25"
#
# "$1,004.68"
#
# "NO"
#
# "Mr"
#
# "H."
#
# "FRANKLIN"
#
# "PERCIVÁL"
#
# "303"
#
# "NATIONAL"
#
# "CENTÉR"
#
# "RĖSTON"
#
# "VA"
#
# "20192"
#
# "US"
#
# "Letter"
#
# "Married"
#
# "BENNY"
#
# "CHEUK"
#
# "6"
#
# "years"
#
# "Legal"
#
# "Exécutive"
#
# "Tech"
#
# "Ok"
#
# "1829.00"
#
# "US"
#
# "DOL/OSHA"
#
# "BONY"
#
# "MELLON"
#
# "ELT"
#
# "SMS"
#
# "TRÜST"
#
# "1994-B"
# bounds: (582,83),(621,83),(621,90),(582,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0006.jpeg
#
# "00367640 HQPW-713078 487872746322 FGY6728 / 24 $36,000.00 12.36%
# 15 months
# $41,562.00 $2,770.80
# Y
# Jr
# ARNOLD ACOSTA
# 345 MIDDLEFIELD RD MS 977
# MENLO PARK CA
# 94025
# USA
# Email
# NA
# CHANÁH EINBINDER
# 6 years
# Asst Accountant
# Téch
# Ok
# 4884.00
# DOL OASAM HRC
# UNIVERSAL CITY STUDIOS CU
# "
#
# "00367640"
#
# "HQPW-713078"
#
# "487872746322"
#
# "FGY6728"
#
# "/"
#
# "24"
#
# "$36,000.00"
#
# "12.36%"
#
# "15"
#
# "months"
#
# "$41,562.00"
#
# "$2,770.80"
#
# "Y"
#
# "Jr"
#
# "ARNOLD"
#
# "ACOSTA"
#
# "345"
#
# "MIDDLEFIELD"
#
# "RD"
#
# "MS"
#
# "977"
#
# "MENLO"
#
# "PARK"
#
# "CA"
#
# "94025"
#
# "USA"
#
# "Email"
#
# "NA"
#
# "CHANÁH"
#
# "EINBINDER"
#
# "6"
#
# "years"
#
# "Asst"
#
# "Accountant"
#
# "Téch"
#
# "Ok"
#
# "4884.00"
#
# "DOL"
#
# "OASAM"
#
# "HRC"
#
# "UNIVERSAL"
#
# "CITY"
#
# "STUDIOS"
#
# "CU"
# bounds: (586,82),(592,82),(592,93),(586,93)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0007.jpeg
#
# "00367641
# ZENI-776538
# 462332885362
# XTW6463 / 07
# $47,000.00 10.61%
# 15 months
# $53,233.38 $3,548.89
# Yes
# Mr
# RÖBERT M WYLAND
# 345 MIDDLEFIELD RD MS 999
# MENLO PÁRK
# CA
# 94025
# Åmerica
# Email
# Married
# DÅLE BIMLER
# 7 years
# HR Manager Support
# Ok
# 6287.00
# DOL OASAM HRC
# WACHOVÍA BANK NA
# "
#
# "00367641"
#
# "ZENI-776538"
#
# "462332885362"
#
# "XTW6463"
#
# "/"
#
# "07"
#
# "$47,000.00"
#
# "10.61%"
#
# "15"
#
# "months"
#
# "$53,233.38"
#
# "$3,548.89"
#
# "Yes"
#
# "Mr"
#
# "RÖBERT"
#
# "M"
#
# "WYLAND"
#
# "345"
#
# "MIDDLEFIELD"
#
# "RD"
#
# "MS"
#
# "999"
#
# "MENLO"
#
# "PÁRK"
#
# "CA"
#
# "94025"
#
# "Åmerica"
#
# "Email"
#
# "Married"
#
# "DÅLE"
#
# "BIMLER"
#
# "7"
#
# "years"
#
# "HR"
#
# "Manager"
#
# "Support"
#
# "Ok"
#
# "6287.00"
#
# "DOL"
#
# "OASAM"
#
# "HRC"
#
# "WACHOVÍA"
#
# "BANK"
#
# "NA"
# bounds: (554,83),(568,83),(568,90),(554,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0008.jpeg
#
# "00367642
# GKCG-114774 788577186306 USS0735 /31 $39,000.00 12.50%
# 21 months
# $47,531.25 $2,263.39
# No
# Jr
# PATRICIA M SADLÉR
# 720 GRACERN RD
# COLUMBIÀ
# SC
# 29210
# USA
# Mobilé
# NA
# MARGARET ALLENDER
# 11 years
# Asst Manager
# Not Available
# Ok
# 3763.00
# MINE SAFETY & HEALTH
# GREENVILLE FEDERAL CREDIT UNION
# "
#
# "00367642"
#
# "GKCG-114774"
#
# "788577186306"
#
# "USS0735"
#
# "/31"
#
# "$39,000.00"
#
# "12.50%"
#
# "21"
#
# "months"
#
# "$47,531.25"
#
# "$2,263.39"
#
# "No"
#
# "Jr"
#
# "PATRICIA"
#
# "M"
#
# "SADLÉR"
#
# "720"
#
# "GRACERN"
#
# "RD"
#
# "COLUMBIÀ"
#
# "SC"
#
# "29210"
#
# "USA"
#
# "Mobilé"
#
# "NA"
#
# "MARGARET"
#
# "ALLENDER"
#
# "11"
#
# "years"
#
# "Asst"
#
# "Manager"
#
# "Not"
#
# "Available"
#
# "Ok"
#
# "3763.00"
#
# "MINE"
#
# "SAFETY"
#
# "&"
#
# "HEALTH"
#
# "GREENVILLE"
#
# "FEDERAL"
#
# "CREDIT"
#
# "UNION"
# bounds: (586,83),(621,83),(621,90),(586,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0009.jpeg
#
# "00367643
# DHPG-845076 521770758435 CXY5634/ 13 $23,000.00 12.25%
# 18 months
# $27,226.25 $1,512.57
# N.
# Mr
# ANDREW I GREISE
# 5522 RESÉARCH PARK DRIVE
# CATONSVILLE MD
# 21228
# US
# Married
# 8 years
# Central Supervisór Productión
# Letter
# JERRY BRANDY
# Ok
# 2659.00
# DOL EBSA
# FIRST EAGLE FCU
# "
#
# "00367643"
#
# "DHPG-845076"
#
# "521770758435"
#
# "CXY5634/"
#
# "13"
#
# "$23,000.00"
#
# "12.25%"
#
# "18"
#
# "months"
#
# "$27,226.25"
#
# "$1,512.57"
#
# "N."
#
# "Mr"
#
# "ANDREW"
#
# "I"
#
# "GREISE"
#
# "5522"
#
# "RESÉARCH"
#
# "PARK"
#
# "DRIVE"
#
# "CATONSVILLE"
#
# "MD"
#
# "21228"
#
# "US"
#
# "Married"
#
# "8"
#
# "years"
#
# "Central"
#
# "Supervisór"
#
# "Productión"
#
# "Letter"
#
# "JERRY"
#
# "BRANDY"
#
# "Ok"
#
# "2659.00"
#
# "DOL"
#
# "EBSA"
#
# "FIRST"
#
# "EAGLE"
#
# "FCU"
# bounds: (498,83),(518,83),(518,90),(498,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0010.jpeg
#
# "00367644
# QWIN-843206
# 527100113733
# OMS7121 / 38 $11,000.00 12.38%
# 18 months
# $13,042.70 $724.59
# Yes
# MR
# LONNIÉ R LANHAM
# 5522 RESEARCH PÀRK DRIVE
# CÀTONSVILLE MD
# 21228
# USA
# Email
# NA
# CYPRIAN MAYEMBA
# 8 years
# Guard
# Support
# Ok
# 1240.00
# US DEPT OF LABOR OSHA
# SANDY SPRING BANK
# "
#
# "00367644"
#
# "QWIN-843206"
#
# "527100113733"
#
# "OMS7121"
#
# "/"
#
# "38"
#
# "$11,000.00"
#
# "12.38%"
#
# "18"
#
# "months"
#
# "$13,042.70"
#
# "$724.59"
#
# "Yes"
#
# "MR"
#
# "LONNIÉ"
#
# "R"
#
# "LANHAM"
#
# "5522"
#
# "RESEARCH"
#
# "PÀRK"
#
# "DRIVE"
#
# "CÀTONSVILLE"
#
# "MD"
#
# "21228"
#
# "USA"
#
# "Email"
#
# "NA"
#
# "CYPRIAN"
#
# "MAYEMBA"
#
# "8"
#
# "years"
#
# "Guard"
#
# "Support"
#
# "Ok"
#
# "1240.00"
#
# "US"
#
# "DEPT"
#
# "OF"
#
# "LABOR"
#
# "OSHA"
#
# "SANDY"
#
# "SPRING"
#
# "BANK"
# bounds: (550,83),(580,83),(580,90),(550,90)
# ------------------다음 이미지 -------------------
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0011.jpeg
#
# "00367645
# RDKC-850437 53432146714i QST7283 / 15 $18,000.00 12.51%
# 18 months
# $21,377.70 $1,187.65
# Yes
# Mr
# DEBORAH BASSÈTT
# 202 NATIONÀL CENTER
# RESTON
# VA
# 20192
# USA
# Émail
# Married
# BARON VENTURÁ
# 8 years
# Próject Assistant
# Support
# Ok
# 2063.00
# US DOL OIG OI
# VANTRIA FEDERAL CREDIT UNION
# "
#
# "00367645"
#
# "RDKC-850437"
#
# "53432146714i"
#
# "QST7283"
#
# "/"
#
# "15"
#
# "$18,000.00"
#
# "12.51%"
#
# "18"
#
# "months"
#
# "$21,377.70"
#
# "$1,187.65"
#
# "Yes"
#
# "Mr"
#
# "DEBORAH"
#
# "BASSÈTT"
#
# "202"
#
# "NATIONÀL"
#
# "CENTER"
#
# "RESTON"
#
# "VA"
#
# "20192"
#
# "USA"
#
# "Émail"
#
# "Married"
#
# "BARON"
#
# "VENTURÁ"
#
# "8"
#
# "years"
#
# "Próject"
#
# "Assistant"
#
# "Support"
#
# "Ok"
#
# "2063.00"
#
# "US"
#
# "DOL"
#
# "OIG"
#
# "OI"
#
# "VANTRIA"
#
# "FEDERAL"
#
# "CREDIT"
#
# "UNION"
# bounds: (566,83),(601,83),(601,90),(566,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0012.jpeg
#
# "00367646
# ESEJ-107015 773817307358 SZU0678 / 30 $133,000.00 12.40%
# 21 months
# $161,861.00 $7,707.67
# No
# MR
# MEGAN M MCWAYNE
# PLACER HALL 6000 J ST
# SACRAMÉNTO CA
# 95819
# ÜS
# Mobile
# 11 years
# Grocers Suppliér Not Available
# NA
# ALFRED GEORGE
# Ok
# 12704.00
# US DOL ATELS BAT
# TYCO FCU
# "
#
# "00367646"
#
# "ESEJ-107015"
#
# "773817307358"
#
# "SZU0678"
#
# "/"
#
# "30"
#
# "$133,000.00"
#
# "12.40%"
#
# "21"
#
# "months"
#
# "$161,861.00"
#
# "$7,707.67"
#
# "No"
#
# "MR"
#
# "MEGAN"
#
# "M"
#
# "MCWAYNE"
#
# "PLACER"
#
# "HALL"
#
# "6000"
#
# "J"
#
# "ST"
#
# "SACRAMÉNTO"
#
# "CA"
#
# "95819"
#
# "ÜS"
#
# "Mobile"
#
# "11"
#
# "years"
#
# "Grocers"
#
# "Suppliér"
#
# "Not"
#
# "Available"
#
# "NA"
#
# "ALFRED"
#
# "GEORGE"
#
# "Ok"
#
# "12704.00"
#
# "US"
#
# "DOL"
#
# "ATELS"
#
# "BAT"
#
# "TYCO"
#
# "FCU"
# bounds: (455,83),(476,83),(476,90),(455,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0013.jpeg
#
# "00367647
# GNVO-655288
# 330082387220
# FDE3737 / 84 $44,000.00 11.57%
# 12 months
# $49,090.80
# $4,090.90
# no
# Mr
# JOHN Á REED
# MODOC HALL USGS MS 3001 3020 STATE UNIV DR EAST SACRAMÉNTO CA
# 95819
# united state
# Sr Managér
# SUN PACIFIC FEDERAL CREDIT UNION
# Letter
# Singie
# CHRISTA ARGUINCHONA
# 5 years
# Markéting
# Ok
# 7463.00
# DIRECTORATE OF CONSTRUCTION
# "
#
# "00367647"
#
# "GNVO-655288"
#
# "330082387220"
#
# "FDE3737"
#
# "/"
#
# "84"
#
# "$44,000.00"
#
# "11.57%"
#
# "12"
#
# "months"
#
# "$49,090.80"
#
# "$4,090.90"
#
# "no"
#
# "Mr"
#
# "JOHN"
#
# "Á"
#
# "REED"
#
# "MODOC"
#
# "HALL"
#
# "USGS"
#
# "MS"
#
# "3001"
#
# "3020"
#
# "STATE"
#
# "UNIV"
#
# "DR"
#
# "EAST"
#
# "SACRAMÉNTO"
#
# "CA"
#
# "95819"
#
# "united"
#
# "state"
#
# "Sr"
#
# "Managér"
#
# "SUN"
#
# "PACIFIC"
#
# "FEDERAL"
#
# "CREDIT"
#
# "UNION"
#
# "Letter"
#
# "Singie"
#
# "CHRISTA"
#
# "ARGUINCHONA"
#
# "5"
#
# "years"
#
# "Markéting"
#
# "Ok"
#
# "7463.00"
#
# "DIRECTORATE"
#
# "OF"
#
# "CONSTRUCTION"
# bounds: (326,79),(419,79),(419,92),(326,92)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0014.jpeg
#
# "00367648 DLST-408710 173613636333 CBA3676 / 03 $21,000.00 11.71%
# 9 months
# $22,844.33 $2,538.26
# NO
# Mr
# DAVID A LAIRSON
# 3039 AMWILER RD STĖ 130
# ATLANTA
# GA
# 30360
# United State
# Letter
# Single
# EVLIN SACHMECHI
# 1 years
# Asst Accountant
# Promo
# Ok
# 4881.00
# DOL ESA OWCP DFEC
# NORTHWEST GEORGIA CREDĪT UNION
# "
#
# "00367648"
#
# "DLST-408710"
#
# "173613636333"
#
# "CBA3676"
#
# "/"
#
# "03"
#
# "$21,000.00"
#
# "11.71%"
#
# "9"
#
# "months"
#
# "$22,844.33"
#
# "$2,538.26"
#
# "NO"
#
# "Mr"
#
# "DAVID"
#
# "A"
#
# "LAIRSON"
#
# "3039"
#
# "AMWILER"
#
# "RD"
#
# "STĖ"
#
# "130"
#
# "ATLANTA"
#
# "GA"
#
# "30360"
#
# "United"
#
# "State"
#
# "Letter"
#
# "Single"
#
# "EVLIN"
#
# "SACHMECHI"
#
# "1"
#
# "years"
#
# "Asst"
#
# "Accountant"
#
# "Promo"
#
# "Ok"
#
# "4881.00"
#
# "DOL"
#
# "ESA"
#
# "OWCP"
#
# "DFEC"
#
# "NORTHWEST"
#
# "GEORGIA"
#
# "CREDĪT"
#
# "UNION"
# bounds: (588,83),(623,83),(623,90),(588,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0015.jpeg
#
# "00367649 WZQF-462360 157263784473 UOZ4322 / 76 $11,000.00 11.70%
# 9 months
# $11,965.25 $1,329.47
# NO
# Mr
# MARITZA B SARSICH
# 10500 UNV CTR DR STE 215 MS 156
# MIÁMI
# FL
# 33178
# united state
# Letter
# Divorced
# AMBER SPERBECK
# 2 years
# Officé Assistant IT
# Ok
# 2496.00
# DOL BLS
# BONY MELLÖN ELT BARCLAYS
# "
#
# "00367649"
#
# "WZQF-462360"
#
# "157263784473"
#
# "UOZ4322"
#
# "/"
#
# "76"
#
# "$11,000.00"
#
# "11.70%"
#
# "9"
#
# "months"
#
# "$11,965.25"
#
# "$1,329.47"
#
# "NO"
#
# "Mr"
#
# "MARITZA"
#
# "B"
#
# "SARSICH"
#
# "10500"
#
# "UNV"
#
# "CTR"
#
# "DR"
#
# "STE"
#
# "215"
#
# "MS"
#
# "156"
#
# "MIÁMI"
#
# "FL"
#
# "33178"
#
# "united"
#
# "state"
#
# "Letter"
#
# "Divorced"
#
# "AMBER"
#
# "SPERBECK"
#
# "2"
#
# "years"
#
# "Officé"
#
# "Assistant"
#
# "IT"
#
# "Ok"
#
# "2496.00"
#
# "DOL"
#
# "BLS"
#
# "BONY"
#
# "MELLÖN"
#
# "ELT"
#
# "BARCLAYS"
# bounds: (530,83),(590,83),(590,90),(530,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0016.jpeg
#
# "DEWY-204562 878365456512 RLM2633 / 50
# $14,000.00 10.59%
# 6 months
# 00367650
# $14,741.30 $2,456.88
# No
# KATHLEEN E PIETRYKA
# mr
# 11649 LEETOWN ROAD
# KEARNEYSVILLE WV
# 25430
# United State of America
# Mobile
# Divorced
# DONALD BLUNKALL
# 14 years
# Security Member Service
# Ok
# 4763.00
# ÜS DOL RI OA
# CITIZENS NATIONAL BANK OF BERKELEY
# "
#
# "DEWY-204562"
#
# "878365456512"
#
# "RLM2633"
#
# "/"
#
# "50"
#
# "$14,000.00"
#
# "10.59%"
#
# "6"
#
# "months"
#
# "00367650"
#
# "$14,741.30"
#
# "$2,456.88"
#
# "No"
#
# "KATHLEEN"
#
# "E"
#
# "PIETRYKA"
#
# "mr"
#
# "11649"
#
# "LEETOWN"
#
# "ROAD"
#
# "KEARNEYSVILLE"
#
# "WV"
#
# "25430"
#
# "United"
#
# "State"
#
# "of"
#
# "America"
#
# "Mobile"
#
# "Divorced"
#
# "DONALD"
#
# "BLUNKALL"
#
# "14"
#
# "years"
#
# "Security"
#
# "Member"
#
# "Service"
#
# "Ok"
#
# "4763.00"
#
# "ÜS"
#
# "DOL"
#
# "RI"
#
# "OA"
#
# "CITIZENS"
#
# "NATIONAL"
#
# "BANK"
#
# "OF"
#
# "BERKELEY"
# bounds: (599,83),(655,83),(655,90),(599,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0017.jpeg
#
# "00367651
# PTQG-784416 460200753631 OIZ4120 / 08 $20,000.00 12.25%
# 15 months
# $23,062.50 $1,537.50
# NO
# Mr
# RYAN L FOSNESS
# 230 COLLINS RD
# BÖISE
# ID
# 83702
# US
# Married
# ESSIÈ CHILLOUSs
# 7 years
# Central Supérvisor Support
# Letter
# Ok
# 2789.00
# US DEPT OF LABOR-ÈTA
# FIRST FEDERAL
# "
#
# "00367651"
#
# "PTQG-784416"
#
# "460200753631"
#
# "OIZ4120"
#
# "/"
#
# "08"
#
# "$20,000.00"
#
# "12.25%"
#
# "15"
#
# "months"
#
# "$23,062.50"
#
# "$1,537.50"
#
# "NO"
#
# "Mr"
#
# "RYAN"
#
# "L"
#
# "FOSNESS"
#
# "230"
#
# "COLLINS"
#
# "RD"
#
# "BÖISE"
#
# "ID"
#
# "83702"
#
# "US"
#
# "Married"
#
# "ESSIÈ"
#
# "CHILLOUSs"
#
# "7"
#
# "years"
#
# "Central"
#
# "Supérvisor"
#
# "Support"
#
# "Letter"
#
# "Ok"
#
# "2789.00"
#
# "US"
#
# "DEPT"
#
# "OF"
#
# "LABOR-ÈTA"
#
# "FIRST"
#
# "FEDERAL"
# bounds: (455,83),(504,83),(504,90),(455,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0018.jpeg
#
# "00367652
# CIKN-782637
# 476531117048
# AXT6515 / 33 $7,000.00 12.38% 15 months
# $8,083.25
# $538.88
# Y
# Jr
# LAWRENCE E ROBERTS
# MODOC HALL STE 4003 CSUS 3020 STÀTE UNIV DR E
# SACRAMENTO CA
# 95819
# USA
# Email
# NA
# DANIELLE ABURLISON
# 7 years
# Guard
# Tech
# Ok
# 1038.00
# DOL BLS
# HIGH DESÉRT FCU
# "
#
# "00367652"
#
# "CIKN-782637"
#
# "476531117048"
#
# "AXT6515"
#
# "/"
#
# "33"
#
# "$7,000.00"
#
# "12.38%"
#
# "15"
#
# "months"
#
# "$8,083.25"
#
# "$538.88"
#
# "Y"
#
# "Jr"
#
# "LAWRENCE"
#
# "E"
#
# "ROBERTS"
#
# "MODOC"
#
# "HALL"
#
# "STE"
#
# "4003"
#
# "CSUS"
#
# "3020"
#
# "STÀTE"
#
# "UNIV"
#
# "DR"
#
# "E"
#
# "SACRAMENTO"
#
# "CA"
#
# "95819"
#
# "USA"
#
# "Email"
#
# "NA"
#
# "DANIELLE"
#
# "ABURLISON"
#
# "7"
#
# "years"
#
# "Guard"
#
# "Tech"
#
# "Ok"
#
# "1038.00"
#
# "DOL"
#
# "BLS"
#
# "HIGH"
#
# "DESÉRT"
#
# "FCU"
# bounds: (568,83),(588,83),(588,90),(568,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0019.jpeg
#
# "00367653 PMVK-348711
# 023604107808
# OBD3176 / 54
# $8,000.00 11.27%
# 6 months
# $8,450.80 $1,408.47
# ANTHONY A BROWN
# no
# mr
# PLACER HALL 6000 J ST
# SACRAMENTO
# CA
# 95819
# United State
# Letter
# Divorced
# BRYAN GREGG
# 15 years
# Supervisor
# Field
# Ok
# 2962.00
# OIG OA HEADQÜARTERS
# UNION BANK CA ELT CÈFI
# "
#
# "00367653"
#
# "PMVK-348711"
#
# "023604107808"
#
# "OBD3176"
#
# "/"
#
# "54"
#
# "$8,000.00"
#
# "11.27%"
#
# "6"
#
# "months"
#
# "$8,450.80"
#
# "$1,408.47"
#
# "ANTHONY"
#
# "A"
#
# "BROWN"
#
# "no"
#
# "mr"
#
# "PLACER"
#
# "HALL"
#
# "6000"
#
# "J"
#
# "ST"
#
# "SACRAMENTO"
#
# "CA"
#
# "95819"
#
# "United"
#
# "State"
#
# "Letter"
#
# "Divorced"
#
# "BRYAN"
#
# "GREGG"
#
# "15"
#
# "years"
#
# "Supervisor"
#
# "Field"
#
# "Ok"
#
# "2962.00"
#
# "OIG"
#
# "OA"
#
# "HEADQÜARTERS"
#
# "UNION"
#
# "BANK"
#
# "CA"
#
# "ELT"
#
# "CÈFI"
# bounds: (555,80),(579,80),(579,90),(555,90)
# ------------------다음 이미지 -------------------
#
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0020.jpeg
#
# "00367654 RSVZ-355132 030835552216 FAL2248 / 54 $9,000.00 10.67%
# 6 months
# $9,480.15 $1,580.03
# no
# mr
# AYLA B AULT
# 1201 WEST UNIV AVENUĖ STE 100
# URBANÀ
# IL
# 61801
# Åmerica
# Mobile
# Divorced
# CHRISTINA CHERPAK
# 15 years Machinist
# Field
# Ok
# 3284.00
# USDOL RÉGION V1 OSHA
# ADLÈR SCHOOL OF PROF PSYCH
# "
#
# "00367654"
#
# "RSVZ-355132"
#
# "030835552216"
#
# "FAL2248"
#
# "/"
#
# "54"
#
# "$9,000.00"
#
# "10.67%"
#
# "6"
#
# "months"
#
# "$9,480.15"
#
# "$1,580.03"
#
# "no"
#
# "mr"
#
# "AYLA"
#
# "B"
#
# "AULT"
#
# "1201"
#
# "WEST"
#
# "UNIV"
#
# "AVENUĖ"
#
# "STE"
#
# "100"
#
# "URBANÀ"
#
# "IL"
#
# "61801"
#
# "Åmerica"
#
# "Mobile"
#
# "Divorced"
#
# "CHRISTINA"
#
# "CHERPAK"
#
# "15"
#
# "years"
#
# "Machinist"
#
# "Field"
#
# "Ok"
#
# "3284.00"
#
# "USDOL"
#
# "RÉGION"
#
# "V1"
#
# "OSHA"
#
# "ADLÈR"
#
# "SCHOOL"
#
# "OF"
#
# "PROF"
#
# "PSYCH"
# bounds: (551,83),(587,83),(587,90),(551,90)
# ------------------다음 이미지 -------------------

# %% [markdown]
# ## 2. KERAS

# %%
# keras-ocr이 detector과 recognizer를 위한 모델을 자동으로 다운로드받게 됩니다. 
pipeline = keras_ocr.pipeline.Pipeline()
# Out:
# Looking for /home/ssac15/.keras-ocr/craft_mlt_25k.h5
# WARNING:tensorflow:From /home/ssac15/Downloads/downloads/envs/aiffel/lib/python3.7/site-packages/tensorflow/python/keras/backend.py:5871: sparse_to_dense (from tensorflow.python.ops.sparse_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Create a `tf.sparse.SparseTensor` and use `tf.sparse.to_dense` instead.
# Looking for /home/ssac15/.keras-ocr/crnn_kurapan.h5

# %%
images = [ keras_ocr.tools.read(img) for img in img_list]
prediction_groups = [pipeline.recognize([img]) for img in img_list]
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe1ac0848c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe1ac0848c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:5 out of the last 11 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe1ac0848c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe1ac0848c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function Model.make_predict_function.<locals>.predict_function at 0x7fe1ac0848c0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings is likely due to passing python objects instead of tensors. Also, tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. Please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for more details.

# %%
# Plot the predictions
fig, axs = plt.subplots(nrows=len(images), figsize=(150, 150))
for idx, ax in enumerate(axs):
    keras_ocr.tools.drawAnnotations(image=images[idx], 
                                    predictions=prediction_groups[idx][0], ax=ax)

# %% [markdown]
# ## 3. TESSERACT

# %%
def crop_word_regions(image_path ='./images/sample.png', output_path='./output'):
    if not os.path.exists(output_path):
        os.mkdir(output_path)
    custom_oem_psm_config = r'--oem 3 --psm 3'
    image = Image.open(image_path)
    
    recognized_data = pytesseract.image_to_data(
        image, lang='eng',
        config = custom_oem_psm_config,
        output_type = Output.DICT
    )
    
    top_level = max(recognized_data['level'])
    index = 0
    cropped_image_path_list = []
    for i in range(len(recognized_data['level'])):
        level = recognized_data['level'][i]
        
        if level == top_level:
            left = recognized_data['left'][i]
            top = recognized_data['top'][i]
            width = recognized_data['width'][i]
            height = recognized_data['height'][i]
            
            output_img_path = os.path.join(output_path, f"{str(index).zfill(4)}.png")
            print(output_img_path)
            cropped_image = image.crop((
                left,
                top,
                left+width,
                top+height
            ))
            cropped_image.save(output_img_path)
            cropped_image_path_list.append(output_img_path)
            index += 1
    return cropped_image_path_list


work_dir = os.getenv('HOME')+'/aiffel/ocr_python/images/cropped'

for path in img_list:
    cropped_image_path_list = crop_word_regions(path, work_dir)
# Out:
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0044.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0045.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0044.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0045.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0044.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0044.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0045.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0046.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0047.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0048.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0049.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0050.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0044.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0045.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0044.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0000.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0001.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0002.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0003.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0004.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0005.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0006.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0007.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0008.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0009.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0010.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0011.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0012.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0013.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0014.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0015.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0016.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0017.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0018.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0019.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0020.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0021.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0022.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0023.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0024.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0025.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0026.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0027.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0028.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0029.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0030.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0031.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0032.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0033.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0034.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0035.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0036.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0037.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0038.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0039.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0040.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0041.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0042.png
# /home/ssac15/aiffel/ocr_python/images/cropped/0043.png

# %%
def recognize_images(cropped_image_path_list):
    custom_oem_psm_config = r'--oem 3 --psm 7'
    
    for image_path in cropped_image_path_list:
        image = Image.open(image_path)
        recognized_data = pytesseract.image_to_string(
            image, lang = 'eng',
            config = custom_oem_psm_config,
            output_type = Output.DICT
        )
        print(recognized_data['text'])
    print("Done")
    
recognize_images(cropped_image_path_list)
# Out:
# Dt sb / 654
#
# KS A -aSS )
#
# ave soo ZL
#
# FAL 2248 / 54
#
# $3,000.00
#
# LUb6/ “5
#
# _
#
# mMNonth=
#
# $9,480.15
#
# $1,580.03
#
# Pri
#
#
# AY?
#
# =
#
# Alii |
#
# LUT
#
# WES |
#
# UNTY
#
# AVENUE
#
# ~~ |
#
# Lou
#
# URBANA
#
# tt
#
# STRit
#
# America
#
# Mobile
#
# yorcend
#
# LR iS Pie
#
# reer e Roe
#
# >
#
# Yeats
#
# Machinist
#
# eid
#
# Che
#
# Ss /54 1h)
#
# List LL
#
# DEISTON
#
# Wi
#
# | ps
#
# ADLER
#
# “sf Fit (jt
#
# LF
#
# =~ "20)5
#
# eC
#
# Done

# %% [markdown]
# ----

# %% [markdown]
# ### Step3. 테스트 결과 정리
# ---

# %%
plt.imshow(images[5])

# %% [markdown]
# ### 구글 결과 샘플 컷

# %%
detect_text(img_list[5])
# Out:
# Texts: in /home/ssac15/aiffel/ocr_python/images/FPDATA0401img0006.jpeg
#
# "00367640 HQPW-713078 487872746322 FGY6728 / 24 $36,000.00 12.36%
# 15 months
# $41,562.00 $2,770.80
# Y
# Jr
# ARNOLD ACOSTA
# 345 MIDDLEFIELD RD MS 977
# MENLO PARK CA
# 94025
# USA
# Email
# NA
# CHANÁH EINBINDER
# 6 years
# Asst Accountant
# Téch
# Ok
# 4884.00
# DOL OASAM HRC
# UNIVERSAL CITY STUDIOS CU
# "
#
# "00367640"
#
# "HQPW-713078"
#
# "487872746322"
#
# "FGY6728"
#
# "/"
#
# "24"
#
# "$36,000.00"
#
# "12.36%"
#
# "15"
#
# "months"
#
# "$41,562.00"
#
# "$2,770.80"
#
# "Y"
#
# "Jr"
#
# "ARNOLD"
#
# "ACOSTA"
#
# "345"
#
# "MIDDLEFIELD"
#
# "RD"
#
# "MS"
#
# "977"
#
# "MENLO"
#
# "PARK"
#
# "CA"
#
# "94025"
#
# "USA"
#
# "Email"
#
# "NA"
#
# "CHANÁH"
#
# "EINBINDER"
#
# "6"
#
# "years"
#
# "Asst"
#
# "Accountant"
#
# "Téch"
#
# "Ok"
#
# "4884.00"
#
# "DOL"
#
# "OASAM"
#
# "HRC"
#
# "UNIVERSAL"
#
# "CITY"
#
# "STUDIOS"
#
# "CU"
# bounds: (586,82),(592,82),(592,93),(586,93)
# ------------------다음 이미지 -------------------

# %% [markdown]
# ### 케라스 결과 샘플 컷

# %%
print(prediction_groups[5][0])
# Out:
# [('oob6z6a0', array([[ 2.      ,  4.999999],
#        [59.999992,  4.999999],
#        [59.999992, 15.999997],
#        [ 2.      , 15.999997]], dtype=float32)), ('hopwziboze', array([[ 74.,   5.],
#        [158.,   5.],
#        [158.,  17.],
#        [ 74.,  17.]], dtype=float32)), ('487727asbpz', array([[165.,   5.],
#        [251.,   5.],
#        [251.,  16.],
#        [165.,  16.]], dtype=float32)), ('fgy6728', array([[258.,   5.],
#        [310.,   5.],
#        [310.,  16.],
#        [258.,  16.]], dtype=float32)), ('sess', array([[344.13217  ,   4.3566065],
#        [372.46133  ,   5.7730656],
#        [371.88278  ,  17.34414  ],
#        [343.55362  ,  15.927679 ]], dtype=float32)), ('oook', array([[369.,   5.],
#        [397.,   5.],
#        [397.,  16.],
#        [369.,  16.]], dtype=float32)), ('0o0', array([[394.,   5.],
#        [410.,   5.],
#        [410.,  16.],
#        [394.,  16.]], dtype=float32)), ('seco', array([[435.,   5.],
#        [461.,   5.],
#        [461.,  16.],
#        [435.,  16.]], dtype=float32)), ('15', array([[527.,   5.],
#        [543.,   5.],
#        [543.,  16.],
#        [527.,  16.]], dtype=float32)), ('months', array([[545.99994 ,   4.999999],
#        [589.99994 ,   4.999999],
#        [589.99994 ,  15.999997],
#        [545.99994 ,  15.999997]], dtype=float32)), ('y', array([[312.,   7.],
#        [318.,   7.],
#        [318.,  16.],
#        [312.,  16.]], dtype=float32)), ('21', array([[321.,   6.],
#        [337.,   6.],
#        [337.,  16.],
#        [321.,  16.]], dtype=float32)), ('1z', array([[416.,   6.],
#        [437.,   6.],
#        [437.,  16.],
#        [416.,  16.]], dtype=float32)), ('san', array([[ 2.1172066, 23.655863 ],
#        [30.496258 , 25.074814 ],
#        [29.932667 , 36.346634 ],
#        [ 1.5536156, 34.927685 ]], dtype=float32)), ('562', array([[27., 24.],
#        [53., 24.],
#        [53., 35.],
#        [27., 35.]], dtype=float32)), ('o0', array([[52., 24.],
#        [68., 24.],
#        [68., 35.],
#        [52., 35.]], dtype=float32)), ('s2', array([[74., 24.],
#        [95., 24.],
#        [95., 36.],
#        [74., 36.]], dtype=float32)), ('770', array([[ 92.,  24.],
#        [116.,  24.],
#        [116.,  35.],
#        [ 92.,  35.]], dtype=float32)), ('80', array([[117.,  24.],
#        [133.,  24.],
#        [133.,  35.],
#        [117.,  35.]], dtype=float32)), ('arnold', array([[344.,  24.],
#        [394.,  24.],
#        [394.,  35.],
#        [344.,  35.]], dtype=float32)), ('acosta', array([[396.      ,  23.999996],
#        [446.      ,  23.999996],
#        [446.      ,  34.999996],
#        [396.      ,  34.999996]], dtype=float32)), ('sr', array([[256.,  25.],
#        [270.,  25.],
#        [270.,  34.],
#        [256.,  34.]], dtype=float32)), ('885', array([[ 2., 43.],
#        [25., 43.],
#        [25., 54.],
#        [ 2., 54.]], dtype=float32)), ('middlefield', array([[ 27.,  43.],
#        [106.,  43.],
#        [106.,  54.],
#        [ 27.,  54.]], dtype=float32)), ('ms', array([[130.,  43.],
#        [149.,  43.],
#        [149.,  54.],
#        [130.,  54.]], dtype=float32)), ('977', array([[151.,  43.],
#        [173.,  43.],
#        [173.,  54.],
#        [151.,  54.]], dtype=float32)), ('menlo', array([[258.,  43.],
#        [298.,  43.],
#        [298.,  54.],
#        [258.,  54.]], dtype=float32)), ('park', array([[301.,  43.],
#        [335.,  43.],
#        [335.,  54.],
#        [301.,  54.]], dtype=float32)), ('ca', array([[344.,  43.],
#        [362.,  43.],
#        [362.,  54.],
#        [344.,  54.]], dtype=float32)), ('9a025', array([[416.,  43.],
#        [453.,  43.],
#        [453.,  54.],
#        [416.,  54.]], dtype=float32)), ('usa', array([[527.,  43.],
#        [552.,  43.],
#        [552.,  54.],
#        [527.,  54.]], dtype=float32)), ('rd', array([[110.,  44.],
#        [128.,  44.],
#        [128.,  54.],
#        [110.,  54.]], dtype=float32)), ('chanah', array([[164.99998,  61.     ],
#        [214.99998,  61.     ],
#        [214.99998,  73.     ],
#        [164.99998,  73.     ]], dtype=float32)), ('email', array([[ 3., 62.],
#        [35., 62.],
#        [35., 73.],
#        [ 3., 73.]], dtype=float32)), ('einbinder', array([[218.,  62.],
#        [285.,  62.],
#        [285.,  73.],
#        [218.,  73.]], dtype=float32)), ('tech', array([[527.,  62.],
#        [556.,  62.],
#        [556.,  73.],
#        [527.,  73.]], dtype=float32)), ('na', array([[75., 63.],
#        [91., 63.],
#        [91., 73.],
#        [75., 73.]], dtype=float32)), ('5', array([[344.,  63.],
#        [353.,  63.],
#        [353.,  73.],
#        [344.,  73.]], dtype=float32)), ('asst', array([[416.,  63.],
#        [442.,  63.],
#        [442.,  73.],
#        [416.,  73.]], dtype=float32)), ('accountant', array([[445.,  63.],
#        [509.,  63.],
#        [509.,  73.],
#        [445.,  73.]], dtype=float32)), ('years', array([[355.,  64.],
#        [389.,  64.],
#        [389.,  74.],
#        [355.,  74.]], dtype=float32)), ('488a', array([[ 74.,  81.],
#        [105.,  81.],
#        [105.,  92.],
#        [ 74.,  92.]], dtype=float32)), ('0o', array([[106.,  81.],
#        [121.,  81.],
#        [121.,  92.],
#        [106.,  92.]], dtype=float32)), ('dol', array([[165.,  81.],
#        [191.,  81.],
#        [191.,  92.],
#        [165.,  92.]], dtype=float32)), ('oasam', array([[193.,  81.],
#        [237.,  81.],
#        [237.,  92.],
#        [193.,  92.]], dtype=float32)), ('hrg', array([[239.,  81.],
#        [266.,  81.],
#        [266.,  92.],
#        [239.,  92.]], dtype=float32)), ('universal', array([[416.,  81.],
#        [483.,  81.],
#        [483.,  92.],
#        [416.,  92.]], dtype=float32)), ('city', array([[487.,  81.],
#        [516.,  81.],
#        [516.,  92.],
#        [487.,  92.]], dtype=float32)), ('studios', array([[518.,  81.],
#        [572.,  81.],
#        [572.,  92.],
#        [518.,  92.]], dtype=float32)), ('cu', array([[575.,  81.],
#        [594.,  81.],
#        [594.,  93.],
#        [575.,  93.]], dtype=float32)), ('dk', array([[ 2., 82.],
#        [20., 82.],
#        [20., 92.],
#        [ 2., 92.]], dtype=float32))]

# %%
keras_ocr.tools.drawAnnotations(image=images[5],  predictions=prediction_groups[5][0])
# Out:
# /home/ssac15/Downloads/downloads/envs/aiffel/lib/python3.7/site-packages/keras_ocr/tools.py:166: MatplotlibDeprecationWarning: The 's' parameter of annotate() has been renamed 'text' since Matplotlib 3.3; support for the old name will be dropped two minor releases later.
#   horizontalalignment='right' if side == 'left' else 'left')
# <AxesSubplot:>

# %% [markdown]
# ### 테서렉트 결과 샘플 컷

# %%
recognize_images(cropped_image_path_list)
# Out:
# Dt sb / 654
#
# KS A -aSS )
#
# ave soo ZL
#
# FAL 2248 / 54
#
# $3,000.00
#
# LUb6/ “5
#
# _
#
# mMNonth=
#
# $9,480.15
#
# $1,580.03
#
# Pri
#
#
# AY?
#
# =
#
# Alii |
#
# LUT
#
# WES |
#
# UNTY
#
# AVENUE
#
# ~~ |
#
# Lou
#
# URBANA
#
# tt
#
# STRit
#
# America
#
# Mobile
#
# yorcend
#
# LR iS Pie
#
# reer e Roe
#
# >
#
# Yeats
#
# Machinist
#
# eid
#
# Che
#
# Ss /54 1h)
#
# List LL
#
# DEISTON
#
# Wi
#
# | ps
#
# ADLER
#
# “sf Fit (jt
#
# LF
#
# =~ "20)5
#
# eC
#
# Done

# %% [markdown]
# ----
#
#
# ## 루브릭
# ----
# 평가문항	상세기준
#
# 1. OCR을 활용하여 구현하려는 서비스의 기획이 타당한가?
#     * 목표로 하는 서비스가 OCR를 적용 가능하며, OCR을 활용했을 때 더욱 유용해진다.
#
# ---
#
# 2. 모델 평가기준이 명확하고 체계적으로 세워졌는가?
#     * 평가 기준에 부합하는 테스트 데이터의 특징이 무엇인지 명확하게 제시되었다.
#
# ----
#
# 3. 평가기준에 따라 충분한 분량의 테스트가 진행되고 그 결과가 잘 정리되었는가?
#     * 최대 20장까지의 테스트 이미지를 사용해 제시된 평가 기준에 따른 테스트 결과가 잘 정리되어 결론이 도출되었다.

# %% [markdown]
# ## 총평
#
# ### OCR 테스트 이미지를 구하기 힘들었음
#
# * LMS 기준 하나 이미지만 처리되는 학습 코드를 이미지의 목록화 해서 돌리도록 재조정함.
# * 유료 API 인 구글 킹왕짱
# * keras 영문 기준 NOTBAD
# * Tessaract는 인식율이 매우 안좋음
