# %% [markdown]
# ## 20-13. 프로젝트 : Segmentation map으로 도로 이미지 만들기

# %%
import os

data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/train/'
print("number of train examples :", len(os.listdir(data_path)))
# Out:
# number of train examples : 1000

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

plt.figure(figsize=(20,15))
for i in range(1, 7):
    f = data_path + os.listdir(data_path)[np.random.randint(800)]
    img = cv2.imread(f, cv2.IMREAD_COLOR)
    plt.subplot(3,2,i)
    plt.imshow(img)

# %%
#이미지를 하나 열어 아래와 같이 크기를 확인해 보겠습니다
f = data_path + os.listdir(data_path)[0]
img = cv2.imread(f, cv2.IMREAD_COLOR)
print(img.shape)
# Out:
# (256, 512, 3)

# %%
#모델 학습에 사용할 데이터를 (256, 256, 3) 크기의 2개 이미지로 분할하여 사용하면 될 것 같네요.

import tensorflow as tf

def normalize(x):
    x = tf.cast(x, tf.float32)
    return (x/127.5) - 1

def denormalize(x):
    x = (x+1)*127.5
    x = x.numpy()
    return x.astype(np.uint8)

def load_img(img_path):
    img = tf.io.read_file(img_path)
    img = tf.image.decode_image(img, 3)
    
    w = tf.shape(img)[1] // 2
    sketch = img[:, :w, :] 
    sketch = tf.cast(sketch, tf.float32)
    colored = img[:, w:, :] 
    colored = tf.cast(colored, tf.float32)
    return normalize(sketch), normalize(colored)

f = data_path + os.listdir(data_path)[1]
sketch, colored = load_img(f)

plt.figure(figsize=(10,7))
plt.subplot(1,2,1); plt.imshow(denormalize(sketch))
plt.subplot(1,2,2); plt.imshow(denormalize(colored))

# %%
from tensorflow import image
from tensorflow.keras.preprocessing.image import random_rotation

@tf.function() # 빠른 텐서플로 연산을 위해 @tf.function()을 사용합니다. 
def apply_augmentation(sketch, colored):
    stacked = tf.concat([sketch, colored], axis=-1)
    
    _pad = tf.constant([[30,30],[30,30],[0,0]])
    if tf.random.uniform(()) < .5:
        padded = tf.pad(stacked, _pad, "REFLECT")
    else:
        padded = tf.pad(stacked, _pad, "CONSTANT", constant_values=1.)

    out = image.random_crop(padded, size=[256, 256, 6])
    
    out = image.random_flip_left_right(out)
    out = image.random_flip_up_down(out)
    
    if tf.random.uniform(()) < .5:
        degree = tf.random.uniform([], minval=1, maxval=4, dtype=tf.int32)
        out = image.rot90(out, k=degree)
    
    return out[...,:3], out[...,3:]   

print("✅")
# Out:
# ✅

# %% [markdown]
# ### 1. 데이터에 한 가지 이상의 augmentation 방법을 적용하여 학습해주세요. (어떠한 방법을 사용했는지 적어주세요.)
#
# *적용 augmentation
# 1. flip - left_right / up_down
# 2. crop
# 3. rotation - 90

# %%
#구성한 함수를 데이터에 적용해 시각화 해봅시다.

plt.figure(figsize=(15,13))
img_n = 1
for i in range(1, 13, 2):
    augmented_sketch, augmented_colored = apply_augmentation(sketch, colored)
    
    plt.subplot(3,4,i)
    plt.imshow(denormalize(augmented_sketch)); plt.title(f"Image {img_n}")
    plt.subplot(3,4,i+1); 
    plt.imshow(denormalize(augmented_colored)); plt.title(f"Image {img_n}")
    img_n += 1

# %%
#위 과정들을 학습 데이터에 적용하며, 잘 적용되었는지 하나의 이미지만 시각화하여 확인해 보겠습니다.

from tensorflow import data

def get_train(img_path):
    sketch, colored = load_img(img_path)
    sketch, colored = apply_augmentation(sketch, colored)
    return sketch, colored

train_images = data.Dataset.list_files(data_path + "*.jpg")
train_images = train_images.map(get_train).shuffle(100).batch(4)

sample = train_images.take(1)
sample = list(sample.as_numpy_iterator())
sketch, colored = (sample[0][0]+1)*127.5, (sample[0][1]+1)*127.5

plt.figure(figsize=(10,5))
plt.subplot(1,2,1); plt.imshow(sketch[0].astype(np.uint8))
plt.subplot(1,2,2); plt.imshow(colored[0].astype(np.uint8))

# %% [markdown]
# ### 2. 이전에 구현했던 두 개의 Generator 중 Encoder와 Decoder간에 skip connection이 있는 U-Net Generator를 사용해주세요.

# %%
from tensorflow.keras import layers, Input, Model

class EncodeBlock(layers.Layer):
    def __init__(self, n_filters, use_bn=True):
        super(EncodeBlock, self).__init__()
        self.use_bn = use_bn       
        self.conv = layers.Conv2D(n_filters, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.lrelu = layers.LeakyReLU(0.2)

    def call(self, x):
        x = self.conv(x)
        if self.use_bn:
            x = self.batchnorm(x)
        return self.lrelu(x)

    
class DecodeBlock(layers.Layer):
    def __init__(self, f, dropout=True):
        super(DecodeBlock, self).__init__()
        self.dropout = dropout
        self.Transconv = layers.Conv2DTranspose(f, 4, 2, "same", use_bias=False)
        self.batchnorm = layers.BatchNormalization()
        self.relu = layers.ReLU()
        
    def call(self, x):
        x = self.Transconv(x)
        x = self.batchnorm(x)
        if self.dropout:
            x = layers.Dropout(.5)(x)
        return self.relu(x)
    
print("✅")
# Out:
# ✅

# %%
class UNetGenerator(Model):
    def __init__(self):
        super(UNetGenerator, self).__init__()
        encode_filters = [64,128,256,512,512,512,512,512]
        decode_filters = [512,512,512,512,256,128,64]
        
        self.encode_blocks = []
        for i, f in enumerate(encode_filters):
            if i == 0:
                self.encode_blocks.append(EncodeBlock(f, use_bn=False))
            else:
                self.encode_blocks.append(EncodeBlock(f))
        
        self.decode_blocks = []
        for i, f in enumerate(decode_filters):
            if i < 3:
                self.decode_blocks.append(DecodeBlock(f))
            else:
                self.decode_blocks.append(DecodeBlock(f, dropout=False))
        
        self.last_conv = layers.Conv2DTranspose(3, 4, 2, "same", use_bias=False)
    
    def call(self, x):
        features = []
        for block in self.encode_blocks:
            x = block(x)
            features.append(x)
        
        features = features[:-1]
                    
        for block, feat in zip(self.decode_blocks, features[::-1]):
            x = block(x)
            x = layers.Concatenate()([x, feat])
        
        x = self.last_conv(x)
        return x
                
    def get_summary(self, input_shape=(256,256,3)):
        inputs = Input(input_shape)
        return Model(inputs, self.call(inputs)).summary()

print("✅")
# Out:
# ✅

# %%
UNetGenerator().get_summary()
# Out:
# Model: "model_6"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_9 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# encode_block_40 (EncodeBlock)   (None, 128, 128, 64) 3072        input_9[0][0]
# __________________________________________________________________________________________________
# encode_block_41 (EncodeBlock)   (None, 64, 64, 128)  131584      encode_block_40[0][0]
# __________________________________________________________________________________________________
# encode_block_42 (EncodeBlock)   (None, 32, 32, 256)  525312      encode_block_41[0][0]
# __________________________________________________________________________________________________
# encode_block_43 (EncodeBlock)   (None, 16, 16, 512)  2099200     encode_block_42[0][0]
# __________________________________________________________________________________________________
# encode_block_44 (EncodeBlock)   (None, 8, 8, 512)    4196352     encode_block_43[0][0]
# __________________________________________________________________________________________________
# encode_block_45 (EncodeBlock)   (None, 4, 4, 512)    4196352     encode_block_44[0][0]
# __________________________________________________________________________________________________
# encode_block_46 (EncodeBlock)   (None, 2, 2, 512)    4196352     encode_block_45[0][0]
# __________________________________________________________________________________________________
# encode_block_47 (EncodeBlock)   (None, 1, 1, 512)    4196352     encode_block_46[0][0]
# __________________________________________________________________________________________________
# decode_block_35 (DecodeBlock)   (None, 2, 2, 512)    4196352     encode_block_47[0][0]
# __________________________________________________________________________________________________
# concatenate_35 (Concatenate)    (None, 2, 2, 1024)   0           decode_block_35[0][0]
#                                                                  encode_block_46[0][0]
# __________________________________________________________________________________________________
# decode_block_36 (DecodeBlock)   (None, 4, 4, 512)    8390656     concatenate_35[0][0]
# __________________________________________________________________________________________________
# concatenate_36 (Concatenate)    (None, 4, 4, 1024)   0           decode_block_36[0][0]
#                                                                  encode_block_45[0][0]
# __________________________________________________________________________________________________
# decode_block_37 (DecodeBlock)   (None, 8, 8, 512)    8390656     concatenate_36[0][0]
# __________________________________________________________________________________________________
# concatenate_37 (Concatenate)    (None, 8, 8, 1024)   0           decode_block_37[0][0]
#                                                                  encode_block_44[0][0]
# __________________________________________________________________________________________________
# decode_block_38 (DecodeBlock)   (None, 16, 16, 512)  8390656     concatenate_37[0][0]
# __________________________________________________________________________________________________
# concatenate_38 (Concatenate)    (None, 16, 16, 1024) 0           decode_block_38[0][0]
#                                                                  encode_block_43[0][0]
# __________________________________________________________________________________________________
# decode_block_39 (DecodeBlock)   (None, 32, 32, 256)  4195328     concatenate_38[0][0]
# __________________________________________________________________________________________________
# concatenate_39 (Concatenate)    (None, 32, 32, 512)  0           decode_block_39[0][0]
#                                                                  encode_block_42[0][0]
# __________________________________________________________________________________________________
# decode_block_40 (DecodeBlock)   (None, 64, 64, 128)  1049088     concatenate_39[0][0]
# __________________________________________________________________________________________________
# concatenate_40 (Concatenate)    (None, 64, 64, 256)  0           decode_block_40[0][0]
#                                                                  encode_block_41[0][0]
# __________________________________________________________________________________________________
# decode_block_41 (DecodeBlock)   (None, 128, 128, 64) 262400      concatenate_40[0][0]
# __________________________________________________________________________________________________
# concatenate_41 (Concatenate)    (None, 128, 128, 128 0           decode_block_41[0][0]
#                                                                  encode_block_40[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_47 (Conv2DTran (None, 256, 256, 3)  6144        concatenate_41[0][0]
# ==================================================================================================
# Total params: 54,425,856
# Trainable params: 54,414,976
# Non-trainable params: 10,880
# __________________________________________________________________________________________________

# %%
class DiscBlock(layers.Layer):
    def __init__(self, n_filters, stride=2, custom_pad=False, use_bn=True, act=True):
        super(DiscBlock, self).__init__()
        self.custom_pad = custom_pad
        self.use_bn = use_bn
        self.act = act
        
        if custom_pad:
            self.padding = layers.ZeroPadding2D()
            self.conv = layers.Conv2D(n_filters, 4, stride, "valid", use_bias=False)
        else:
            self.conv = layers.Conv2D(n_filters, 4, stride, "same", use_bias=False)
        
        self.batchnorm = layers.BatchNormalization() if use_bn else None
        self.lrelu = layers.LeakyReLU(0.2) if act else None
        
    def call(self, x):
        if self.custom_pad:
            x = self.padding(x)
            x = self.conv(x)
        else:
            x = self.conv(x)
                
        if self.use_bn:
            x = self.batchnorm(x)
            
        if self.act:
            x = self.lrelu(x)
        return x 

print("✅")
# Out:
# ✅

# %%
inputs = Input((128,128,32))
out = layers.ZeroPadding2D()(inputs)
out = layers.Conv2D(64, 4, 1, "valid", use_bias=False)(out)
out = layers.BatchNormalization()(out)
out = layers.LeakyReLU(0.2)(out)

Model(inputs, out).summary()
# Out:
# Model: "model_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_10 (InputLayer)        [(None, 128, 128, 32)]    0
# _________________________________________________________________
# zero_padding2d_16 (ZeroPaddi (None, 130, 130, 32)      0
# _________________________________________________________________
# conv2d_85 (Conv2D)           (None, 127, 127, 64)      32768
# _________________________________________________________________
# batch_normalization_113 (Bat (None, 127, 127, 64)      256
# _________________________________________________________________
# leaky_re_lu_78 (LeakyReLU)   (None, 127, 127, 64)      0
# =================================================================
# Total params: 33,024
# Trainable params: 32,896
# Non-trainable params: 128
# _________________________________________________________________

# %%
class Discriminator(Model):
    def __init__(self):
        super(Discriminator, self).__init__()
        
        self.block1 = layers.Concatenate()
        self.block2 = DiscBlock(n_filters=64, stride=2, custom_pad=False, use_bn=False, act=True)
        self.block3 = DiscBlock(n_filters=128, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block4 = DiscBlock(n_filters=256, stride=2, custom_pad=False, use_bn=True, act=True)
        self.block5 = DiscBlock(n_filters=512, stride=1, custom_pad=True, use_bn=True, act=True)
        self.block6 = DiscBlock(n_filters=1, stride=1, custom_pad=True, use_bn=False, act=False)
        self.sigmoid = layers.Activation("sigmoid")
        
        # filters = [64,128,256,512,1]
        # self.blocks = [layers.Concatenate()]
        # for i, f in enumerate(filters):
        #     self.blocks.append(DiscBlock(
        #         n_filters=f,
        #         strides=2 if i<3 else 1,
        #         custom_pad=False if i<3 else True,
        #         use_bn=False if i==0 and i==4 else True,
        #         act=True if i<4 else False
        #     ))
    
    def call(self, x, y):
        out = self.block1([x, y])
        out = self.block2(out)
        out = self.block3(out)
        out = self.block4(out)
        out = self.block5(out)
        out = self.block6(out)
        return self.sigmoid(out)
    
    def get_summary(self, x_shape=(256,256,3), y_shape=(256,256,3)):
        x, y = Input(x_shape), Input(y_shape) 
        return Model((x, y), self.call(x, y)).summary()
    
print("✅")
# Out:
# ✅

# %%
Discriminator().get_summary()
# Out:
# Model: "model_8"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_11 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# input_12 (InputLayer)           [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# concatenate_42 (Concatenate)    (None, 256, 256, 6)  0           input_11[0][0]
#                                                                  input_12[0][0]
# __________________________________________________________________________________________________
# disc_block_35 (DiscBlock)       (None, 128, 128, 64) 6144        concatenate_42[0][0]
# __________________________________________________________________________________________________
# disc_block_36 (DiscBlock)       (None, 64, 64, 128)  131584      disc_block_35[0][0]
# __________________________________________________________________________________________________
# disc_block_37 (DiscBlock)       (None, 32, 32, 256)  525312      disc_block_36[0][0]
# __________________________________________________________________________________________________
# disc_block_38 (DiscBlock)       (None, 31, 31, 512)  2099200     disc_block_37[0][0]
# __________________________________________________________________________________________________
# disc_block_39 (DiscBlock)       (None, 30, 30, 1)    8192        disc_block_38[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 30, 30, 1)    0           disc_block_39[0][0]
# ==================================================================================================
# Total params: 2,770,432
# Trainable params: 2,768,640
# Non-trainable params: 1,792
# __________________________________________________________________________________________________

# %%
#시험 삼아 임의의 (256,256,3) 크기의 입력을 넣어 나오는 (30,30) 출력을 시각화해보겠습니다.

x = tf.random.normal([1,256,256,3])
y = tf.random.uniform([1,256,256,3])

disc_out = Discriminator()(x, y)
plt.imshow(disc_out[0, ... ,0])
plt.colorbar()

# %% [markdown]
# ### 손실함수

# %%
from tensorflow.keras import losses

bce = losses.BinaryCrossentropy(from_logits=False)
mae = losses.MeanAbsoluteError()

def get_gene_loss(fake_output, real_output, fake_disc):
    l1_loss = mae(real_output, fake_output)
    gene_loss = bce(tf.ones_like(fake_disc), fake_disc)
    return gene_loss, l1_loss

def get_disc_loss(fake_disc, real_disc):
    return bce(tf.zeros_like(fake_disc), fake_disc) + bce(tf.ones_like(real_disc), real_disc)

print("✅")
# Out:
# ✅

# %% [markdown]
# Generator 및 Discriminator의 손실 계산을 각각 정의했습니다.
#
# ### optimizer

# %%
from tensorflow.keras import optimizers

gene_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)
disc_opt = optimizers.Adam(2e-4, beta_1=.5, beta_2=.999)

print("✅")
# Out:
# ✅

# %%
@tf.function
def train_step(sketch, real_colored):
    with tf.GradientTape() as gene_tape, tf.GradientTape() as disc_tape:
        # Generator 예측
        fake_colored = generator(sketch, training=True)
        # Discriminator 예측
        fake_disc = discriminator(sketch, fake_colored, training=True)
        real_disc = discriminator(sketch, real_colored, training=True)
        # Generator 손실 계산
        gene_loss, l1_loss = get_gene_loss(fake_colored, real_colored, fake_disc)
        gene_total_loss = gene_loss + (100 * l1_loss) ## <===== L1 손실 반영 λ=100
        # Discrminator 손실 계산
        disc_loss = get_disc_loss(fake_disc, real_disc)
                
    gene_gradient = gene_tape.gradient(gene_total_loss, generator.trainable_variables)
    disc_gradient = disc_tape.gradient(disc_loss, discriminator.trainable_variables)
    
    gene_opt.apply_gradients(zip(gene_gradient, generator.trainable_variables))
    disc_opt.apply_gradients(zip(disc_gradient, discriminator.trainable_variables))
    return gene_loss, l1_loss, disc_loss

print("✅")
# Out:
# ✅

# %%
EPOCHS = 100

generator = UNetGenerator()
discriminator = Discriminator()

for epoch in range(1, EPOCHS+1):
    for i, (sketch, colored) in enumerate(train_images):
        g_loss, l1_loss, d_loss = train_step(sketch, colored)
                
        # 10회 반복마다 손실을 출력합니다.
        if (i+1) % 10 == 0:
            print(f"EPOCH[{epoch}] - STEP[{i+1}] \
                    \nGenerator_loss:{g_loss.numpy():.4f} \
                    \nL1_loss:{l1_loss.numpy():.4f} \
                    \nDiscriminator_loss:{d_loss.numpy():.4f}", end="\n\n")
# Out:
# EPOCH[1] - STEP[10]
# Generator_loss:1.0311
# L1_loss:0.3443
# Discriminator_loss:1.4973
#
# EPOCH[1] - STEP[20]
# Generator_loss:1.1795
# L1_loss:0.3277
# Discriminator_loss:1.0067
#
# EPOCH[1] - STEP[30]
# Generator_loss:1.3750
# L1_loss:0.2419
# Discriminator_loss:0.8731
#
# EPOCH[1] - STEP[40]
# Generator_loss:1.3723
# L1_loss:0.2430
# Discriminator_loss:1.0618
#
# EPOCH[1] - STEP[50]
# Generator_loss:1.4830
# L1_loss:0.2274
# Discriminator_loss:0.7615
#
# EPOCH[1] - STEP[60]
# Generator_loss:1.7725
# L1_loss:0.2659
# Discriminator_loss:0.8025
#
# EPOCH[1] - STEP[70]
# Generator_loss:1.2082
# L1_loss:0.2681
# Discriminator_loss:0.7963
#
# EPOCH[1] - STEP[80]
# Generator_loss:2.1077
# L1_loss:0.2489
# Discriminator_loss:0.3410
#
# EPOCH[1] - STEP[90]
# Generator_loss:2.0588
# L1_loss:0.2083
# Discriminator_loss:0.8321
#
# EPOCH[1] - STEP[100]
# Generator_loss:1.3129
# L1_loss:0.2683
# Discriminator_loss:0.8206
#
# EPOCH[1] - STEP[110]
# Generator_loss:1.0240
# L1_loss:0.2831
# Discriminator_loss:0.8113
#
# EPOCH[1] - STEP[120]
# Generator_loss:1.6389
# L1_loss:0.2130
# Discriminator_loss:0.7547
#
# EPOCH[1] - STEP[130]
# Generator_loss:1.9302
# L1_loss:0.2000
# Discriminator_loss:0.8331
#
# EPOCH[1] - STEP[140]
# Generator_loss:2.0386
# L1_loss:0.2246
# Discriminator_loss:0.5572
#
# EPOCH[1] - STEP[150]
# Generator_loss:2.5459
# L1_loss:0.2059
# Discriminator_loss:0.7844
#
# EPOCH[1] - STEP[160]
# Generator_loss:2.4808
# L1_loss:0.2040
# Discriminator_loss:0.7086
#
# EPOCH[1] - STEP[170]
# Generator_loss:1.7294
# L1_loss:0.2159
# Discriminator_loss:0.6109
#
# EPOCH[1] - STEP[180]
# Generator_loss:2.8684
# L1_loss:0.2226
# Discriminator_loss:0.6379
#
# EPOCH[1] - STEP[190]
# Generator_loss:2.6104
# L1_loss:0.1951
# Discriminator_loss:0.4224
#
# EPOCH[1] - STEP[200]
# Generator_loss:0.9737
# L1_loss:0.1845
# Discriminator_loss:0.9855
#
# EPOCH[1] - STEP[210]
# Generator_loss:1.4265
# L1_loss:0.2213
# Discriminator_loss:0.5753
#
# EPOCH[1] - STEP[220]
# Generator_loss:2.5524
# L1_loss:0.2231
# Discriminator_loss:0.5314
#
# EPOCH[1] - STEP[230]
# Generator_loss:2.9549
# L1_loss:0.2554
# Discriminator_loss:0.4143
#
# EPOCH[1] - STEP[240]
# Generator_loss:1.9863
# L1_loss:0.1990
# Discriminator_loss:0.7198
#
# EPOCH[1] - STEP[250]
# Generator_loss:2.6718
# L1_loss:0.2108
# Discriminator_loss:0.7421
#
# EPOCH[2] - STEP[10]
# Generator_loss:2.0039
# L1_loss:0.2588
# Discriminator_loss:0.3619
#
# EPOCH[2] - STEP[20]
# Generator_loss:0.9561
# L1_loss:0.2308
# Discriminator_loss:0.7561
#
# EPOCH[2] - STEP[30]
# Generator_loss:1.0206
# L1_loss:0.2639
# Discriminator_loss:0.7550
#
# EPOCH[2] - STEP[40]
# Generator_loss:1.0213
# L1_loss:0.2202
# Discriminator_loss:0.9472
#
# EPOCH[2] - STEP[50]
# Generator_loss:2.1546
# L1_loss:0.1884
# Discriminator_loss:1.0423
#
# EPOCH[2] - STEP[60]
# Generator_loss:1.2008
# L1_loss:0.2672
# Discriminator_loss:0.7768
#
# EPOCH[2] - STEP[70]
# Generator_loss:1.3493
# L1_loss:0.1874
# Discriminator_loss:1.6850
#
# EPOCH[2] - STEP[80]
# Generator_loss:2.4498
# L1_loss:0.2101
# Discriminator_loss:0.3615
#
# EPOCH[2] - STEP[90]
# Generator_loss:1.8566
# L1_loss:0.1866
# Discriminator_loss:0.4298
#
# EPOCH[2] - STEP[100]
# Generator_loss:1.2569
# L1_loss:0.2347
# Discriminator_loss:0.8661
#
# EPOCH[2] - STEP[110]
# Generator_loss:2.4899
# L1_loss:0.2119
# Discriminator_loss:0.7380
#
# EPOCH[2] - STEP[120]
# Generator_loss:1.1906
# L1_loss:0.2193
# Discriminator_loss:0.6333
#
# EPOCH[2] - STEP[130]
# Generator_loss:2.3737
# L1_loss:0.1841
# Discriminator_loss:0.9966
#
# EPOCH[2] - STEP[140]
# Generator_loss:2.5314
# L1_loss:0.1688
# Discriminator_loss:0.5715
#
# EPOCH[2] - STEP[150]
# Generator_loss:1.0123
# L1_loss:0.1815
# Discriminator_loss:1.0456
#
# EPOCH[2] - STEP[160]
# Generator_loss:1.7468
# L1_loss:0.2065
# Discriminator_loss:0.3405
#
# EPOCH[2] - STEP[170]
# Generator_loss:0.9843
# L1_loss:0.1770
# Discriminator_loss:0.7653
#
# EPOCH[2] - STEP[180]
# Generator_loss:3.7866
# L1_loss:0.1621
# Discriminator_loss:1.7928
#
# EPOCH[2] - STEP[190]
# Generator_loss:1.7674
# L1_loss:0.2433
# Discriminator_loss:0.4062
#
# EPOCH[2] - STEP[200]
# Generator_loss:1.2395
# L1_loss:0.2229
# Discriminator_loss:0.5709
#
# EPOCH[2] - STEP[210]
# Generator_loss:2.3391
# L1_loss:0.2438
# Discriminator_loss:0.4757
#
# EPOCH[2] - STEP[220]
# Generator_loss:2.7060
# L1_loss:0.2028
# Discriminator_loss:0.3377
#
# EPOCH[2] - STEP[230]
# Generator_loss:2.1629
# L1_loss:0.2271
# Discriminator_loss:0.8330
#
# EPOCH[2] - STEP[240]
# Generator_loss:1.3088
# L1_loss:0.1859
# Discriminator_loss:0.6969
#
# EPOCH[2] - STEP[250]
# Generator_loss:2.1340
# L1_loss:0.1859
# Discriminator_loss:0.4858
#
# EPOCH[3] - STEP[10]
# Generator_loss:2.9284
# L1_loss:0.2278
# Discriminator_loss:0.1603
#
# EPOCH[3] - STEP[20]
# Generator_loss:2.9963
# L1_loss:0.1830
# Discriminator_loss:0.9594
#
# EPOCH[3] - STEP[30]
# Generator_loss:1.1798
# L1_loss:0.2118
# Discriminator_loss:0.7921
#
# EPOCH[3] - STEP[40]
# Generator_loss:2.5841
# L1_loss:0.1886
# Discriminator_loss:1.1688
#
# EPOCH[3] - STEP[50]
# Generator_loss:2.5048
# L1_loss:0.1993
# Discriminator_loss:1.2152
#
# EPOCH[3] - STEP[60]
# Generator_loss:1.7586
# L1_loss:0.2220
# Discriminator_loss:0.5921
# EPOCH[3] - STEP[70]
# Generator_loss:3.1589
# L1_loss:0.2627
# Discriminator_loss:0.2262
#
# EPOCH[3] - STEP[80]
# Generator_loss:2.5373
# L1_loss:0.2107
# Discriminator_loss:0.8298
#
# EPOCH[3] - STEP[90]
# Generator_loss:1.7235
# L1_loss:0.2170
# Discriminator_loss:0.5083
#
# EPOCH[3] - STEP[100]
# Generator_loss:1.4757
# L1_loss:0.2426
# Discriminator_loss:1.2802
#
# EPOCH[3] - STEP[110]
# Generator_loss:2.3894
# L1_loss:0.1640
# Discriminator_loss:0.5177
#
# EPOCH[3] - STEP[120]
# Generator_loss:1.0249
# L1_loss:0.1997
# Discriminator_loss:0.5676
#
# EPOCH[3] - STEP[130]
# Generator_loss:1.0772
# L1_loss:0.1862
# Discriminator_loss:0.6378
#
# EPOCH[3] - STEP[140]
# Generator_loss:2.2764
# L1_loss:0.2824
# Discriminator_loss:0.9028
#
# EPOCH[3] - STEP[150]
# Generator_loss:1.0650
# L1_loss:0.2042
# Discriminator_loss:0.5319
#
# EPOCH[3] - STEP[160]
# Generator_loss:1.2297
# L1_loss:0.1691
# Discriminator_loss:1.4540
#
# EPOCH[3] - STEP[170]
# Generator_loss:0.4556
# L1_loss:0.2007
# Discriminator_loss:1.4584
#
# EPOCH[3] - STEP[180]
# Generator_loss:1.2372
# L1_loss:0.1744
# Discriminator_loss:1.0362
#
# EPOCH[3] - STEP[190]
# Generator_loss:1.8505
# L1_loss:0.1733
# Discriminator_loss:0.6772
#
# EPOCH[3] - STEP[200]
# Generator_loss:2.0515
# L1_loss:0.2278
# Discriminator_loss:0.6066
#
# EPOCH[3] - STEP[210]
# Generator_loss:2.2470
# L1_loss:0.1656
# Discriminator_loss:0.6133
#
# EPOCH[3] - STEP[220]
# Generator_loss:1.0342
# L1_loss:0.2648
# Discriminator_loss:0.6653
#
# EPOCH[3] - STEP[230]
# Generator_loss:2.6983
# L1_loss:0.2032
# Discriminator_loss:1.3220
#
# EPOCH[3] - STEP[240]
# Generator_loss:3.6807
# L1_loss:0.1710
# Discriminator_loss:1.8809
#
# EPOCH[3] - STEP[250]
# Generator_loss:1.4349
# L1_loss:0.1844
# Discriminator_loss:0.5128
#
# EPOCH[4] - STEP[10]
# Generator_loss:2.4056
# L1_loss:0.1855
# Discriminator_loss:1.0112
#
# EPOCH[4] - STEP[20]
# Generator_loss:0.6335
# L1_loss:0.2162
# Discriminator_loss:0.9532
#
# EPOCH[4] - STEP[30]
# Generator_loss:2.6456
# L1_loss:0.2201
# Discriminator_loss:0.4695
#
# EPOCH[4] - STEP[40]
# Generator_loss:1.0818
# L1_loss:0.2100
# Discriminator_loss:0.6043
#
# EPOCH[4] - STEP[50]
# Generator_loss:3.5627
# L1_loss:0.1803
# Discriminator_loss:1.0475
#
# EPOCH[4] - STEP[60]
# Generator_loss:0.4902
# L1_loss:0.1880
# Discriminator_loss:1.6609
#
# EPOCH[4] - STEP[70]
# Generator_loss:2.4117
# L1_loss:0.1871
# Discriminator_loss:0.6897
#
# EPOCH[4] - STEP[80]
# Generator_loss:1.9615
# L1_loss:0.1996
# Discriminator_loss:0.3746
#
# EPOCH[4] - STEP[90]
# Generator_loss:0.5347
# L1_loss:0.1864
# Discriminator_loss:1.2398
#
# EPOCH[4] - STEP[100]
# Generator_loss:1.8941
# L1_loss:0.2357
# Discriminator_loss:0.6606
#
# EPOCH[4] - STEP[110]
# Generator_loss:1.2298
# L1_loss:0.2268
# Discriminator_loss:0.6458
#
# EPOCH[4] - STEP[120]
# Generator_loss:2.0293
# L1_loss:0.1913
# Discriminator_loss:0.4428
#
# EPOCH[4] - STEP[130]
# Generator_loss:2.8395
# L1_loss:0.1670
# Discriminator_loss:0.6050
#
# EPOCH[4] - STEP[140]
# Generator_loss:2.1054
# L1_loss:0.2036
# Discriminator_loss:0.3449
#
# EPOCH[4] - STEP[150]
# Generator_loss:3.0651
# L1_loss:0.2105
# Discriminator_loss:0.4130
#
# EPOCH[4] - STEP[160]
# Generator_loss:1.4476
# L1_loss:0.1653
# Discriminator_loss:1.0684
#
# EPOCH[4] - STEP[170]
# Generator_loss:3.2517
# L1_loss:0.1876
# Discriminator_loss:1.2951
#
# EPOCH[4] - STEP[180]
# Generator_loss:2.7824
# L1_loss:0.2005
# Discriminator_loss:0.8054
#
# EPOCH[4] - STEP[190]
# Generator_loss:2.1595
# L1_loss:0.2123
# Discriminator_loss:0.4897
#
# EPOCH[4] - STEP[200]
# Generator_loss:1.9156
# L1_loss:0.1711
# Discriminator_loss:0.7019
#
# EPOCH[4] - STEP[210]
# Generator_loss:3.4262
# L1_loss:0.1727
# Discriminator_loss:1.1891
#
# EPOCH[4] - STEP[220]
# Generator_loss:1.1093
# L1_loss:0.2090
# Discriminator_loss:0.9956
#
# EPOCH[4] - STEP[230]
# Generator_loss:1.7452
# L1_loss:0.2142
# Discriminator_loss:0.3173
#
# EPOCH[4] - STEP[240]
# Generator_loss:2.0657
# L1_loss:0.1810
# Discriminator_loss:0.8819
#
# EPOCH[4] - STEP[250]
# Generator_loss:2.9807
# L1_loss:0.1753
# Discriminator_loss:1.1669
#
# EPOCH[5] - STEP[10]
# Generator_loss:2.4857
# L1_loss:0.1832
# Discriminator_loss:0.4428
#
# EPOCH[5] - STEP[20]
# Generator_loss:2.3083
# L1_loss:0.1942
# Discriminator_loss:0.8059
#
# EPOCH[5] - STEP[30]
# Generator_loss:1.4062
# L1_loss:0.1857
# Discriminator_loss:1.0513
#
# EPOCH[5] - STEP[40]
# Generator_loss:1.0191
# L1_loss:0.1872
# Discriminator_loss:0.6429
#
# EPOCH[5] - STEP[50]
# Generator_loss:0.4479
# L1_loss:0.1705
# Discriminator_loss:1.2495
#
# EPOCH[5] - STEP[60]
# Generator_loss:1.2910
# L1_loss:0.1850
# Discriminator_loss:0.6367
#
# EPOCH[5] - STEP[70]
# Generator_loss:2.2761
# L1_loss:0.1804
# Discriminator_loss:0.5149
#
# EPOCH[5] - STEP[80]
# Generator_loss:1.2975
# L1_loss:0.2055
# Discriminator_loss:0.7237
#
# EPOCH[5] - STEP[90]
# Generator_loss:1.4841
# L1_loss:0.2354
# Discriminator_loss:0.6575
#
# EPOCH[5] - STEP[100]
# Generator_loss:1.3494
# L1_loss:0.1923
# Discriminator_loss:0.5652
#
# EPOCH[5] - STEP[110]
# Generator_loss:1.4007
# L1_loss:0.2131
# Discriminator_loss:0.7091
#
# EPOCH[5] - STEP[120]
# Generator_loss:3.5597
# L1_loss:0.1622
# Discriminator_loss:1.4711
# EPOCH[5] - STEP[130]
# Generator_loss:2.8125
# L1_loss:0.1985
# Discriminator_loss:0.4152
#
# EPOCH[5] - STEP[140]
# Generator_loss:2.4423
# L1_loss:0.2273
# Discriminator_loss:0.2340
#
# EPOCH[5] - STEP[150]
# Generator_loss:1.5357
# L1_loss:0.1637
# Discriminator_loss:0.7013
#
# EPOCH[5] - STEP[160]
# Generator_loss:1.2339
# L1_loss:0.2007
# Discriminator_loss:1.1039
#
# EPOCH[5] - STEP[170]
# Generator_loss:1.0074
# L1_loss:0.2343
# Discriminator_loss:0.8261
#
# EPOCH[5] - STEP[180]
# Generator_loss:1.8666
# L1_loss:0.2369
# Discriminator_loss:0.3053
#
# EPOCH[5] - STEP[190]
# Generator_loss:0.9961
# L1_loss:0.1803
# Discriminator_loss:0.8042
#
# EPOCH[5] - STEP[200]
# Generator_loss:1.7218
# L1_loss:0.1659
# Discriminator_loss:0.5366
#
# EPOCH[5] - STEP[210]
# Generator_loss:2.0667
# L1_loss:0.2265
# Discriminator_loss:0.2776
#
# EPOCH[5] - STEP[220]
# Generator_loss:1.3912
# L1_loss:0.1863
# Discriminator_loss:0.5186
#
# EPOCH[5] - STEP[230]
# Generator_loss:1.1697
# L1_loss:0.1978
# Discriminator_loss:0.7303
#
# EPOCH[5] - STEP[240]
# Generator_loss:1.8868
# L1_loss:0.1855
# Discriminator_loss:0.4595
#
# EPOCH[5] - STEP[250]
# Generator_loss:2.0803
# L1_loss:0.1964
# Discriminator_loss:0.9433
#
# EPOCH[6] - STEP[10]
# Generator_loss:2.4563
# L1_loss:0.1755
# Discriminator_loss:1.3706
#
# EPOCH[6] - STEP[20]
# Generator_loss:1.6468
# L1_loss:0.1919
# Discriminator_loss:0.3765
#
# EPOCH[6] - STEP[30]
# Generator_loss:2.5928
# L1_loss:0.2067
# Discriminator_loss:0.6701
#
# EPOCH[6] - STEP[40]
# Generator_loss:2.4591
# L1_loss:0.1825
# Discriminator_loss:0.6109
#
# EPOCH[6] - STEP[50]
# Generator_loss:3.6779
# L1_loss:0.2273
# Discriminator_loss:0.1584
#
# EPOCH[6] - STEP[60]
# Generator_loss:3.0614
# L1_loss:0.1851
# Discriminator_loss:0.1902
#
# EPOCH[6] - STEP[70]
# Generator_loss:0.8875
# L1_loss:0.2007
# Discriminator_loss:0.9197
#
# EPOCH[6] - STEP[80]
# Generator_loss:0.6885
# L1_loss:0.1512
# Discriminator_loss:1.1652
#
# EPOCH[6] - STEP[90]
# Generator_loss:1.9827
# L1_loss:0.1896
# Discriminator_loss:0.3570
#
# EPOCH[6] - STEP[100]
# Generator_loss:1.4511
# L1_loss:0.2213
# Discriminator_loss:0.4383
#
# EPOCH[6] - STEP[110]
# Generator_loss:1.5698
# L1_loss:0.1811
# Discriminator_loss:0.7696
#
# EPOCH[6] - STEP[120]
# Generator_loss:0.5591
# L1_loss:0.1891
# Discriminator_loss:1.0910
#
# EPOCH[6] - STEP[130]
# Generator_loss:1.6964
# L1_loss:0.1800
# Discriminator_loss:0.8890
#
# EPOCH[6] - STEP[140]
# Generator_loss:3.0645
# L1_loss:0.2137
# Discriminator_loss:0.1903
#
# EPOCH[6] - STEP[150]
# Generator_loss:0.9660
# L1_loss:0.1778
# Discriminator_loss:0.6499
#
# EPOCH[6] - STEP[160]
# Generator_loss:1.4566
# L1_loss:0.2017
# Discriminator_loss:0.7962
#
# EPOCH[6] - STEP[170]
# Generator_loss:1.2700
# L1_loss:0.1862
# Discriminator_loss:0.6824
#
# EPOCH[6] - STEP[180]
# Generator_loss:2.0608
# L1_loss:0.1653
# Discriminator_loss:1.1797
#
# EPOCH[6] - STEP[190]
# Generator_loss:2.1800
# L1_loss:0.2033
# Discriminator_loss:0.6902
#
# EPOCH[6] - STEP[200]
# Generator_loss:0.7773
# L1_loss:0.1794
# Discriminator_loss:1.1651
#
# EPOCH[6] - STEP[210]
# Generator_loss:1.9811
# L1_loss:0.2171
# Discriminator_loss:0.8142
#
# EPOCH[6] - STEP[220]
# Generator_loss:1.7579
# L1_loss:0.2133
# Discriminator_loss:0.5434
#
# EPOCH[6] - STEP[230]
# Generator_loss:0.8568
# L1_loss:0.2057
# Discriminator_loss:0.9163
#
# EPOCH[6] - STEP[240]
# Generator_loss:2.6877
# L1_loss:0.1590
# Discriminator_loss:0.4271
#
# EPOCH[6] - STEP[250]
# Generator_loss:2.5962
# L1_loss:0.1907
# Discriminator_loss:0.5557
#
# EPOCH[7] - STEP[10]
# Generator_loss:1.4372
# L1_loss:0.1894
# Discriminator_loss:0.6816
#
# EPOCH[7] - STEP[20]
# Generator_loss:0.3371
# L1_loss:0.1766
# Discriminator_loss:1.5740
#
# EPOCH[7] - STEP[30]
# Generator_loss:1.2916
# L1_loss:0.2076
# Discriminator_loss:0.7783
#
# EPOCH[7] - STEP[40]
# Generator_loss:2.2674
# L1_loss:0.2004
# Discriminator_loss:0.6787
#
# EPOCH[7] - STEP[50]
# Generator_loss:3.8111
# L1_loss:0.1845
# Discriminator_loss:0.5482
#
# EPOCH[7] - STEP[60]
# Generator_loss:2.1549
# L1_loss:0.1731
# Discriminator_loss:0.5609
#
# EPOCH[7] - STEP[70]
# Generator_loss:1.1767
# L1_loss:0.2218
# Discriminator_loss:0.6806
#
# EPOCH[7] - STEP[80]
# Generator_loss:1.9329
# L1_loss:0.1695
# Discriminator_loss:1.2565
#
# EPOCH[7] - STEP[90]
# Generator_loss:1.2261
# L1_loss:0.1520
# Discriminator_loss:0.7617
#
# EPOCH[7] - STEP[100]
# Generator_loss:0.4803
# L1_loss:0.1715
# Discriminator_loss:1.1627
#
# EPOCH[7] - STEP[110]
# Generator_loss:2.5563
# L1_loss:0.1813
# Discriminator_loss:0.2632
#
# EPOCH[7] - STEP[120]
# Generator_loss:0.4611
# L1_loss:0.1777
# Discriminator_loss:1.1962
#
# EPOCH[7] - STEP[130]
# Generator_loss:2.1832
# L1_loss:0.1523
# Discriminator_loss:0.8048
#
# EPOCH[7] - STEP[140]
# Generator_loss:2.5500
# L1_loss:0.1607
# Discriminator_loss:1.3377
#
# EPOCH[7] - STEP[150]
# Generator_loss:1.6401
# L1_loss:0.2058
# Discriminator_loss:0.3238
#
# EPOCH[7] - STEP[160]
# Generator_loss:3.7328
# L1_loss:0.2065
# Discriminator_loss:0.6847
#
# EPOCH[7] - STEP[170]
# Generator_loss:2.3872
# L1_loss:0.1674
# Discriminator_loss:0.9251
#
# EPOCH[7] - STEP[180]
# Generator_loss:1.9386
# L1_loss:0.1404
# Discriminator_loss:2.1808
# EPOCH[7] - STEP[190]
# Generator_loss:3.0034
# L1_loss:0.1913
# Discriminator_loss:1.7835
#
# EPOCH[7] - STEP[200]
# Generator_loss:2.0802
# L1_loss:0.1925
# Discriminator_loss:0.7073
#
# EPOCH[7] - STEP[210]
# Generator_loss:1.1474
# L1_loss:0.1675
# Discriminator_loss:0.8040
#
# EPOCH[7] - STEP[220]
# Generator_loss:1.6575
# L1_loss:0.1988
# Discriminator_loss:0.5992
#
# EPOCH[7] - STEP[230]
# Generator_loss:2.0780
# L1_loss:0.2057
# Discriminator_loss:0.7706
#
# EPOCH[7] - STEP[240]
# Generator_loss:1.5420
# L1_loss:0.1723
# Discriminator_loss:0.4625
#
# EPOCH[7] - STEP[250]
# Generator_loss:1.3844
# L1_loss:0.1925
# Discriminator_loss:0.3943
#
# EPOCH[8] - STEP[10]
# Generator_loss:2.1638
# L1_loss:0.1712
# Discriminator_loss:0.9120
#
# EPOCH[8] - STEP[20]
# Generator_loss:1.6052
# L1_loss:0.1771
# Discriminator_loss:0.9191
#
# EPOCH[8] - STEP[30]
# Generator_loss:1.8940
# L1_loss:0.1946
# Discriminator_loss:0.4051
#
# EPOCH[8] - STEP[40]
# Generator_loss:1.9979
# L1_loss:0.1682
# Discriminator_loss:0.4554
#
# EPOCH[8] - STEP[50]
# Generator_loss:1.6137
# L1_loss:0.2026
# Discriminator_loss:0.3143
#
# EPOCH[8] - STEP[60]
# Generator_loss:1.9622
# L1_loss:0.1887
# Discriminator_loss:0.8781
#
# EPOCH[8] - STEP[70]
# Generator_loss:2.6322
# L1_loss:0.1750
# Discriminator_loss:0.7004
#
# EPOCH[8] - STEP[80]
# Generator_loss:0.4003
# L1_loss:0.1734
# Discriminator_loss:1.4647
#
# EPOCH[8] - STEP[90]
# Generator_loss:0.6177
# L1_loss:0.1671
# Discriminator_loss:1.4866
#
# EPOCH[8] - STEP[100]
# Generator_loss:3.1406
# L1_loss:0.2360
# Discriminator_loss:0.2740
#
# EPOCH[8] - STEP[110]
# Generator_loss:1.5906
# L1_loss:0.2329
# Discriminator_loss:0.4143
#
# EPOCH[8] - STEP[120]
# Generator_loss:1.5076
# L1_loss:0.1584
# Discriminator_loss:1.4596
#
# EPOCH[8] - STEP[130]
# Generator_loss:1.7370
# L1_loss:0.1662
# Discriminator_loss:0.6351
#
# EPOCH[8] - STEP[140]
# Generator_loss:1.6692
# L1_loss:0.2229
# Discriminator_loss:0.3470
#
# EPOCH[8] - STEP[150]
# Generator_loss:1.7213
# L1_loss:0.2045
# Discriminator_loss:0.3060
#
# EPOCH[8] - STEP[160]
# Generator_loss:3.4728
# L1_loss:0.1769
# Discriminator_loss:0.7611
#
# EPOCH[8] - STEP[170]
# Generator_loss:1.3386
# L1_loss:0.2143
# Discriminator_loss:0.4457
#
# EPOCH[8] - STEP[180]
# Generator_loss:2.3233
# L1_loss:0.1566
# Discriminator_loss:0.8190
#
# EPOCH[8] - STEP[190]
# Generator_loss:0.5863
# L1_loss:0.2165
# Discriminator_loss:1.0563
#
# EPOCH[8] - STEP[200]
# Generator_loss:1.4945
# L1_loss:0.2442
# Discriminator_loss:0.3929
#
# EPOCH[8] - STEP[210]
# Generator_loss:2.1267
# L1_loss:0.2087
# Discriminator_loss:0.3615
#
# EPOCH[8] - STEP[220]
# Generator_loss:1.4229
# L1_loss:0.1647
# Discriminator_loss:0.7640
#
# EPOCH[8] - STEP[230]
# Generator_loss:1.7946
# L1_loss:0.1714
# Discriminator_loss:0.9679
#
# EPOCH[8] - STEP[240]
# Generator_loss:2.5016
# L1_loss:0.1927
# Discriminator_loss:0.4129
#
# EPOCH[8] - STEP[250]
# Generator_loss:0.8138
# L1_loss:0.1611
# Discriminator_loss:1.3494
#
# EPOCH[9] - STEP[10]
# Generator_loss:1.5835
# L1_loss:0.1707
# Discriminator_loss:0.3258
#
# EPOCH[9] - STEP[20]
# Generator_loss:1.2914
# L1_loss:0.1546
# Discriminator_loss:1.2224
#
# EPOCH[9] - STEP[30]
# Generator_loss:2.1625
# L1_loss:0.1945
# Discriminator_loss:0.3121
#
# EPOCH[9] - STEP[40]
# Generator_loss:2.3348
# L1_loss:0.1675
# Discriminator_loss:0.6271
#
# EPOCH[9] - STEP[50]
# Generator_loss:1.1019
# L1_loss:0.1459
# Discriminator_loss:0.6317
#
# EPOCH[9] - STEP[60]
# Generator_loss:1.0476
# L1_loss:0.2019
# Discriminator_loss:0.6557
#
# EPOCH[9] - STEP[70]
# Generator_loss:2.9452
# L1_loss:0.1878
# Discriminator_loss:1.2537
#
# EPOCH[9] - STEP[80]
# Generator_loss:1.5842
# L1_loss:0.2061
# Discriminator_loss:0.3668
#
# EPOCH[9] - STEP[90]
# Generator_loss:1.2613
# L1_loss:0.1678
# Discriminator_loss:0.6663
#
# EPOCH[9] - STEP[100]
# Generator_loss:2.2912
# L1_loss:0.1847
# Discriminator_loss:0.3167
#
# EPOCH[9] - STEP[110]
# Generator_loss:1.5080
# L1_loss:0.1622
# Discriminator_loss:0.6620
#
# EPOCH[9] - STEP[120]
# Generator_loss:2.3000
# L1_loss:0.1358
# Discriminator_loss:1.1145
#
# EPOCH[9] - STEP[130]
# Generator_loss:1.1987
# L1_loss:0.1700
# Discriminator_loss:0.6543
#
# EPOCH[9] - STEP[140]
# Generator_loss:0.6811
# L1_loss:0.1895
# Discriminator_loss:0.9728
#
# EPOCH[9] - STEP[150]
# Generator_loss:1.9995
# L1_loss:0.1630
# Discriminator_loss:0.5344
#
# EPOCH[9] - STEP[160]
# Generator_loss:2.5142
# L1_loss:0.1990
# Discriminator_loss:0.2504
#
# EPOCH[9] - STEP[170]
# Generator_loss:0.4377
# L1_loss:0.1851
# Discriminator_loss:1.4454
#
# EPOCH[9] - STEP[180]
# Generator_loss:1.8364
# L1_loss:0.2012
# Discriminator_loss:0.5463
#
# EPOCH[9] - STEP[190]
# Generator_loss:1.0408
# L1_loss:0.1563
# Discriminator_loss:0.6628
#
# EPOCH[9] - STEP[200]
# Generator_loss:0.4931
# L1_loss:0.1893
# Discriminator_loss:1.1752
#
# EPOCH[9] - STEP[210]
# Generator_loss:2.3326
# L1_loss:0.1807
# Discriminator_loss:0.4822
#
# EPOCH[9] - STEP[220]
# Generator_loss:2.8922
# L1_loss:0.1702
# Discriminator_loss:0.6884
#
# EPOCH[9] - STEP[230]
# Generator_loss:3.1257
# L1_loss:0.2305
# Discriminator_loss:0.6996
#
# EPOCH[9] - STEP[240]
# Generator_loss:2.0701
# L1_loss:0.1934
# Discriminator_loss:0.6191
# EPOCH[9] - STEP[250]
# Generator_loss:1.2046
# L1_loss:0.2029
# Discriminator_loss:0.4973
#
# EPOCH[10] - STEP[10]
# Generator_loss:1.1254
# L1_loss:0.1527
# Discriminator_loss:1.0471
#
# EPOCH[10] - STEP[20]
# Generator_loss:1.8656
# L1_loss:0.2647
# Discriminator_loss:0.4716
#
# EPOCH[10] - STEP[30]
# Generator_loss:0.9861
# L1_loss:0.2191
# Discriminator_loss:0.6543
#
# EPOCH[10] - STEP[40]
# Generator_loss:1.0338
# L1_loss:0.1726
# Discriminator_loss:0.6498
#
# EPOCH[10] - STEP[50]
# Generator_loss:0.9509
# L1_loss:0.1830
# Discriminator_loss:0.8138
#
# EPOCH[10] - STEP[60]
# Generator_loss:2.4608
# L1_loss:0.1442
# Discriminator_loss:0.5733
#
# EPOCH[10] - STEP[70]
# Generator_loss:1.0980
# L1_loss:0.1578
# Discriminator_loss:0.6875
#
# EPOCH[10] - STEP[80]
# Generator_loss:2.2527
# L1_loss:0.1854
# Discriminator_loss:0.5236
#
# EPOCH[10] - STEP[90]
# Generator_loss:1.8909
# L1_loss:0.1503
# Discriminator_loss:0.7948
#
# EPOCH[10] - STEP[100]
# Generator_loss:0.7103
# L1_loss:0.1684
# Discriminator_loss:1.2835
#
# EPOCH[10] - STEP[110]
# Generator_loss:2.7321
# L1_loss:0.2036
# Discriminator_loss:0.4490
#
# EPOCH[10] - STEP[120]
# Generator_loss:1.5461
# L1_loss:0.1769
# Discriminator_loss:1.1868
#
# EPOCH[10] - STEP[130]
# Generator_loss:1.2074
# L1_loss:0.1697
# Discriminator_loss:0.5278
#
# EPOCH[10] - STEP[140]
# Generator_loss:3.1379
# L1_loss:0.1547
# Discriminator_loss:0.3695
#
# EPOCH[10] - STEP[150]
# Generator_loss:1.9948
# L1_loss:0.1847
# Discriminator_loss:0.4027
#
# EPOCH[10] - STEP[160]
# Generator_loss:2.0246
# L1_loss:0.1671
# Discriminator_loss:0.6983
#
# EPOCH[10] - STEP[170]
# Generator_loss:1.0348
# L1_loss:0.1708
# Discriminator_loss:0.8842
#
# EPOCH[10] - STEP[180]
# Generator_loss:2.1324
# L1_loss:0.2071
# Discriminator_loss:0.7014
#
# EPOCH[10] - STEP[190]
# Generator_loss:1.2800
# L1_loss:0.1999
# Discriminator_loss:1.0280
#
# EPOCH[10] - STEP[200]
# Generator_loss:0.5061
# L1_loss:0.1688
# Discriminator_loss:1.8798
#
# EPOCH[10] - STEP[210]
# Generator_loss:3.7333
# L1_loss:0.1627
# Discriminator_loss:0.8343
#
# EPOCH[10] - STEP[220]
# Generator_loss:1.7129
# L1_loss:0.1785
# Discriminator_loss:1.1352
#
# EPOCH[10] - STEP[230]
# Generator_loss:2.6765
# L1_loss:0.2100
# Discriminator_loss:1.1249
#
# EPOCH[10] - STEP[240]
# Generator_loss:1.6352
# L1_loss:0.1717
# Discriminator_loss:0.3430
#
# EPOCH[10] - STEP[250]
# Generator_loss:4.1530
# L1_loss:0.1825
# Discriminator_loss:1.7663
#
# EPOCH[11] - STEP[10]
# Generator_loss:2.2985
# L1_loss:0.1784
# Discriminator_loss:0.5367
#
# EPOCH[11] - STEP[20]
# Generator_loss:2.3070
# L1_loss:0.2051
# Discriminator_loss:0.1925
#
# EPOCH[11] - STEP[30]
# Generator_loss:0.8664
# L1_loss:0.1758
# Discriminator_loss:0.8295
#
# EPOCH[11] - STEP[40]
# Generator_loss:2.3310
# L1_loss:0.2937
# Discriminator_loss:0.2735
#
# EPOCH[11] - STEP[50]
# Generator_loss:3.6618
# L1_loss:0.2000
# Discriminator_loss:0.1919
#
# EPOCH[11] - STEP[60]
# Generator_loss:0.8384
# L1_loss:0.1694
# Discriminator_loss:0.8686
#
# EPOCH[11] - STEP[70]
# Generator_loss:1.9189
# L1_loss:0.1461
# Discriminator_loss:0.6281
#
# EPOCH[11] - STEP[80]
# Generator_loss:2.4603
# L1_loss:0.1412
# Discriminator_loss:0.8349
#
# EPOCH[11] - STEP[90]
# Generator_loss:2.5787
# L1_loss:0.1726
# Discriminator_loss:0.5040
#
# EPOCH[11] - STEP[100]
# Generator_loss:1.3024
# L1_loss:0.1760
# Discriminator_loss:0.6817
#
# EPOCH[11] - STEP[110]
# Generator_loss:0.5546
# L1_loss:0.1657
# Discriminator_loss:1.0284
#
# EPOCH[11] - STEP[120]
# Generator_loss:3.2519
# L1_loss:0.1375
# Discriminator_loss:1.1779
#
# EPOCH[11] - STEP[130]
# Generator_loss:2.0071
# L1_loss:0.2416
# Discriminator_loss:0.4544
#
# EPOCH[11] - STEP[140]
# Generator_loss:0.6685
# L1_loss:0.2066
# Discriminator_loss:0.8897
#
# EPOCH[11] - STEP[150]
# Generator_loss:0.6024
# L1_loss:0.2340
# Discriminator_loss:0.9616
#
# EPOCH[11] - STEP[160]
# Generator_loss:2.2530
# L1_loss:0.2049
# Discriminator_loss:0.4299
#
# EPOCH[11] - STEP[170]
# Generator_loss:0.6509
# L1_loss:0.2183
# Discriminator_loss:1.5114
#
# EPOCH[11] - STEP[180]
# Generator_loss:1.7750
# L1_loss:0.1891
# Discriminator_loss:0.8783
#
# EPOCH[11] - STEP[190]
# Generator_loss:1.8232
# L1_loss:0.2174
# Discriminator_loss:0.4131
#
# EPOCH[11] - STEP[200]
# Generator_loss:1.9807
# L1_loss:0.1443
# Discriminator_loss:0.5873
#
# EPOCH[11] - STEP[210]
# Generator_loss:2.1561
# L1_loss:0.1719
# Discriminator_loss:0.6455
#
# EPOCH[11] - STEP[220]
# Generator_loss:2.1614
# L1_loss:0.1961
# Discriminator_loss:0.2733
#
# EPOCH[11] - STEP[230]
# Generator_loss:1.5533
# L1_loss:0.1756
# Discriminator_loss:0.3752
#
# EPOCH[11] - STEP[240]
# Generator_loss:0.9422
# L1_loss:0.1916
# Discriminator_loss:0.6901
#
# EPOCH[11] - STEP[250]
# Generator_loss:2.2741
# L1_loss:0.1480
# Discriminator_loss:0.5725
#
# EPOCH[12] - STEP[10]
# Generator_loss:0.4892
# L1_loss:0.1472
# Discriminator_loss:1.4224
#
# EPOCH[12] - STEP[20]
# Generator_loss:2.9522
# L1_loss:0.1574
# Discriminator_loss:0.9538
#
# EPOCH[12] - STEP[30]
# Generator_loss:1.1594
# L1_loss:0.1583
# Discriminator_loss:0.7320
#
# EPOCH[12] - STEP[40]
# Generator_loss:1.9734
# L1_loss:0.1746
# Discriminator_loss:0.6529
#
# EPOCH[12] - STEP[50]
# Generator_loss:2.3236
# L1_loss:0.1708
# Discriminator_loss:0.3592
# EPOCH[12] - STEP[60]
# Generator_loss:1.0615
# L1_loss:0.2056
# Discriminator_loss:0.6337
#
# EPOCH[12] - STEP[70]
# Generator_loss:2.6189
# L1_loss:0.1561
# Discriminator_loss:1.0755
#
# EPOCH[12] - STEP[80]
# Generator_loss:1.1597
# L1_loss:0.1936
# Discriminator_loss:0.5116
#
# EPOCH[12] - STEP[90]
# Generator_loss:1.7307
# L1_loss:0.1822
# Discriminator_loss:0.3364
#
# EPOCH[12] - STEP[100]
# Generator_loss:3.5297
# L1_loss:0.1729
# Discriminator_loss:1.3861
#
# EPOCH[12] - STEP[110]
# Generator_loss:2.8549
# L1_loss:0.1677
# Discriminator_loss:0.2582
#
# EPOCH[12] - STEP[120]
# Generator_loss:1.6024
# L1_loss:0.1730
# Discriminator_loss:0.6130
#
# EPOCH[12] - STEP[130]
# Generator_loss:1.2168
# L1_loss:0.2148
# Discriminator_loss:0.4823
#
# EPOCH[12] - STEP[140]
# Generator_loss:0.9736
# L1_loss:0.1456
# Discriminator_loss:1.3889
#
# EPOCH[12] - STEP[150]
# Generator_loss:2.5308
# L1_loss:0.1701
# Discriminator_loss:0.4612
#
# EPOCH[12] - STEP[160]
# Generator_loss:2.3269
# L1_loss:0.1765
# Discriminator_loss:0.5165
#
# EPOCH[12] - STEP[170]
# Generator_loss:1.3954
# L1_loss:0.2030
# Discriminator_loss:0.5319
#
# EPOCH[12] - STEP[180]
# Generator_loss:1.7272
# L1_loss:0.1948
# Discriminator_loss:0.3230
#
# EPOCH[12] - STEP[190]
# Generator_loss:0.6510
# L1_loss:0.1836
# Discriminator_loss:1.0905
#
# EPOCH[12] - STEP[200]
# Generator_loss:1.7713
# L1_loss:0.1571
# Discriminator_loss:0.5647
#
# EPOCH[12] - STEP[210]
# Generator_loss:2.9137
# L1_loss:0.1997
# Discriminator_loss:0.3087
#
# EPOCH[12] - STEP[220]
# Generator_loss:2.6491
# L1_loss:0.1679
# Discriminator_loss:0.9898
#
# EPOCH[12] - STEP[230]
# Generator_loss:1.9509
# L1_loss:0.1563
# Discriminator_loss:0.8559
#
# EPOCH[12] - STEP[240]
# Generator_loss:1.2349
# L1_loss:0.2002
# Discriminator_loss:0.9923
#
# EPOCH[12] - STEP[250]
# Generator_loss:0.5650
# L1_loss:0.1588
# Discriminator_loss:1.1879
#
# EPOCH[13] - STEP[10]
# Generator_loss:2.4206
# L1_loss:0.1705
# Discriminator_loss:0.3679
#
# EPOCH[13] - STEP[20]
# Generator_loss:2.1406
# L1_loss:0.2122
# Discriminator_loss:0.3706
#
# EPOCH[13] - STEP[30]
# Generator_loss:2.0045
# L1_loss:0.1854
# Discriminator_loss:0.5977
#
# EPOCH[13] - STEP[40]
# Generator_loss:1.7991
# L1_loss:0.1711
# Discriminator_loss:1.0144
#
# EPOCH[13] - STEP[50]
# Generator_loss:1.2200
# L1_loss:0.1703
# Discriminator_loss:0.7403
#
# EPOCH[13] - STEP[60]
# Generator_loss:2.5479
# L1_loss:0.1437
# Discriminator_loss:1.2676
#
# EPOCH[13] - STEP[70]
# Generator_loss:2.1704
# L1_loss:0.1545
# Discriminator_loss:0.2296
#
# EPOCH[13] - STEP[80]
# Generator_loss:3.2809
# L1_loss:0.1763
# Discriminator_loss:0.8312
#
# EPOCH[13] - STEP[90]
# Generator_loss:1.3758
# L1_loss:0.1350
# Discriminator_loss:0.6250
#
# EPOCH[13] - STEP[100]
# Generator_loss:3.2949
# L1_loss:0.1741
# Discriminator_loss:0.4170
#
# EPOCH[13] - STEP[110]
# Generator_loss:1.0738
# L1_loss:0.1809
# Discriminator_loss:0.9142
#
# EPOCH[13] - STEP[120]
# Generator_loss:1.5927
# L1_loss:0.1913
# Discriminator_loss:1.1133
#
# EPOCH[13] - STEP[130]
# Generator_loss:2.1294
# L1_loss:0.1591
# Discriminator_loss:0.4907
#
# EPOCH[13] - STEP[140]
# Generator_loss:1.9935
# L1_loss:0.2030
# Discriminator_loss:0.2660
#
# EPOCH[13] - STEP[150]
# Generator_loss:1.3878
# L1_loss:0.1583
# Discriminator_loss:0.6982
#
# EPOCH[13] - STEP[160]
# Generator_loss:1.2153
# L1_loss:0.1621
# Discriminator_loss:0.7400
#
# EPOCH[13] - STEP[170]
# Generator_loss:2.3503
# L1_loss:0.1445
# Discriminator_loss:1.2761
#
# EPOCH[13] - STEP[180]
# Generator_loss:3.2357
# L1_loss:0.1691
# Discriminator_loss:0.5977
#
# EPOCH[13] - STEP[190]
# Generator_loss:1.6913
# L1_loss:0.1618
# Discriminator_loss:0.5566
#
# EPOCH[13] - STEP[200]
# Generator_loss:1.4717
# L1_loss:0.2244
# Discriminator_loss:0.4042
#
# EPOCH[13] - STEP[210]
# Generator_loss:1.6656
# L1_loss:0.1650
# Discriminator_loss:0.5756
#
# EPOCH[13] - STEP[220]
# Generator_loss:1.5499
# L1_loss:0.1792
# Discriminator_loss:0.3614
#
# EPOCH[13] - STEP[230]
# Generator_loss:2.4977
# L1_loss:0.1721
# Discriminator_loss:0.5127
#
# EPOCH[13] - STEP[240]
# Generator_loss:2.8185
# L1_loss:0.1849
# Discriminator_loss:0.3071
#
# EPOCH[13] - STEP[250]
# ...
# L1_loss:0.1328
# Discriminator_loss:0.8632
#
# EPOCH[96] - STEP[190]
# Generator_loss:5.3582
# L1_loss:0.1384
# Discriminator_loss:0.2037
#
# EPOCH[96] - STEP[200]
# Generator_loss:1.3927
# L1_loss:0.1121
# Discriminator_loss:0.6040
#
# EPOCH[96] - STEP[210]
# Generator_loss:0.9067
# L1_loss:0.1378
# Discriminator_loss:0.7990
#
# EPOCH[96] - STEP[220]
# Generator_loss:2.3614
# L1_loss:0.1444
# Discriminator_loss:0.4263
#
# EPOCH[96] - STEP[230]
# Generator_loss:5.0232
# L1_loss:0.1633
# Discriminator_loss:0.1689
#
# EPOCH[96] - STEP[240]
# Generator_loss:2.1780
# L1_loss:0.1034
# Discriminator_loss:0.7282
#
# EPOCH[96] - STEP[250]
# Generator_loss:2.6825
# L1_loss:0.1300
# Discriminator_loss:0.5461
#
# EPOCH[97] - STEP[10]
# Generator_loss:2.2009
# L1_loss:0.1261
# Discriminator_loss:0.5817
#
# EPOCH[97] - STEP[20]
# Generator_loss:0.6780
# L1_loss:0.1464
# Discriminator_loss:1.1092
#
# EPOCH[97] - STEP[30]
# Generator_loss:3.0322
# L1_loss:0.1407
# Discriminator_loss:0.1362
#
# EPOCH[97] - STEP[40]
# Generator_loss:4.0201
# L1_loss:0.1620
# Discriminator_loss:0.0930
#
# EPOCH[97] - STEP[50]
# Generator_loss:1.8149
# L1_loss:0.1090
# Discriminator_loss:0.6382
#
# EPOCH[97] - STEP[60]
# Generator_loss:4.6221
# L1_loss:0.1183
# Discriminator_loss:0.0828
#
# EPOCH[97] - STEP[70]
# Generator_loss:2.2559
# L1_loss:0.1446
# Discriminator_loss:0.2478
#
# EPOCH[97] - STEP[80]
# Generator_loss:1.6288
# L1_loss:0.1366
# Discriminator_loss:0.3413
# EPOCH[97] - STEP[90]
# Generator_loss:1.3345
# L1_loss:0.1109
# Discriminator_loss:0.5776
#
# EPOCH[97] - STEP[100]
# Generator_loss:1.6762
# L1_loss:0.1104
# Discriminator_loss:0.5601
#
# EPOCH[97] - STEP[110]
# Generator_loss:1.3441
# L1_loss:0.1175
# Discriminator_loss:0.5608
#
# EPOCH[97] - STEP[120]
# Generator_loss:2.9566
# L1_loss:0.1309
# Discriminator_loss:0.5647
#
# EPOCH[97] - STEP[130]
# Generator_loss:3.3571
# L1_loss:0.1146
# Discriminator_loss:0.2220
#
# EPOCH[97] - STEP[140]
# Generator_loss:1.7937
# L1_loss:0.0913
# Discriminator_loss:0.3422
#
# EPOCH[97] - STEP[150]
# Generator_loss:2.8027
# L1_loss:0.1157
# Discriminator_loss:0.2971
#
# EPOCH[97] - STEP[160]
# Generator_loss:3.5611
# L1_loss:0.1555
# Discriminator_loss:0.3096
#
# EPOCH[97] - STEP[170]
# Generator_loss:3.8711
# L1_loss:0.1606
# Discriminator_loss:0.3222
#
# EPOCH[97] - STEP[180]
# Generator_loss:3.5084
# L1_loss:0.1486
# Discriminator_loss:0.0863
#
# EPOCH[97] - STEP[190]
# Generator_loss:2.4649
# L1_loss:0.1329
# Discriminator_loss:0.7873
#
# EPOCH[97] - STEP[200]
# Generator_loss:3.7130
# L1_loss:0.1540
# Discriminator_loss:0.0782
#
# EPOCH[97] - STEP[210]
# Generator_loss:2.4797
# L1_loss:0.0970
# Discriminator_loss:1.7875
#
# EPOCH[97] - STEP[220]
# Generator_loss:2.1539
# L1_loss:0.1421
# Discriminator_loss:0.2052
#
# EPOCH[97] - STEP[230]
# Generator_loss:3.5832
# L1_loss:0.1394
# Discriminator_loss:0.0690
#
# EPOCH[97] - STEP[240]
# Generator_loss:4.4464
# L1_loss:0.1387
# Discriminator_loss:0.4117
#
# EPOCH[97] - STEP[250]
# Generator_loss:5.6044
# L1_loss:0.1524
# Discriminator_loss:0.6948
#
# EPOCH[98] - STEP[10]
# Generator_loss:4.0705
# L1_loss:0.1202
# Discriminator_loss:0.1324
#
# EPOCH[98] - STEP[20]
# Generator_loss:1.8126
# L1_loss:0.1475
# Discriminator_loss:0.2876
#
# EPOCH[98] - STEP[30]
# Generator_loss:3.2828
# L1_loss:0.1404
# Discriminator_loss:0.2880
#
# EPOCH[98] - STEP[40]
# Generator_loss:2.7362
# L1_loss:0.1415
# Discriminator_loss:1.0064
#
# EPOCH[98] - STEP[50]
# Generator_loss:4.1758
# L1_loss:0.1328
# Discriminator_loss:0.1188
#
# EPOCH[98] - STEP[60]
# Generator_loss:5.7670
# L1_loss:0.1115
# Discriminator_loss:0.2373
#
# EPOCH[98] - STEP[70]
# Generator_loss:2.2446
# L1_loss:0.1138
# Discriminator_loss:0.7380
#
# EPOCH[98] - STEP[80]
# Generator_loss:2.7017
# L1_loss:0.1203
# Discriminator_loss:0.9154
#
# EPOCH[98] - STEP[90]
# Generator_loss:0.5303
# L1_loss:0.1339
# Discriminator_loss:1.4325
#
# EPOCH[98] - STEP[100]
# Generator_loss:1.3485
# L1_loss:0.1167
# Discriminator_loss:0.6584
#
# EPOCH[98] - STEP[110]
# Generator_loss:4.3080
# L1_loss:0.1667
# Discriminator_loss:0.0654
#
# EPOCH[98] - STEP[120]
# Generator_loss:2.1536
# L1_loss:0.1664
# Discriminator_loss:0.2293
#
# EPOCH[98] - STEP[130]
# Generator_loss:5.3536
# L1_loss:0.1746
# Discriminator_loss:0.2021
#
# EPOCH[98] - STEP[140]
# Generator_loss:3.1986
# L1_loss:0.1248
# Discriminator_loss:0.1111
#
# EPOCH[98] - STEP[150]
# Generator_loss:3.9269
# L1_loss:0.1508
# Discriminator_loss:0.0829
#
# EPOCH[98] - STEP[160]
# Generator_loss:3.3944
# L1_loss:0.1123
# Discriminator_loss:0.3439
#
# EPOCH[98] - STEP[170]
# Generator_loss:3.0983
# L1_loss:0.1282
# Discriminator_loss:0.3034
#
# EPOCH[98] - STEP[180]
# Generator_loss:2.4231
# L1_loss:0.1345
# Discriminator_loss:0.1972
#
# EPOCH[98] - STEP[190]
# Generator_loss:1.1959
# L1_loss:0.1044
# Discriminator_loss:0.5560
#
# EPOCH[98] - STEP[200]
# Generator_loss:1.4491
# L1_loss:0.1488
# Discriminator_loss:0.5057
#
# EPOCH[98] - STEP[210]
# Generator_loss:4.8991
# L1_loss:0.1063
# Discriminator_loss:0.5607
#
# EPOCH[98] - STEP[220]
# Generator_loss:6.0604
# L1_loss:0.1573
# Discriminator_loss:0.1641
#
# EPOCH[98] - STEP[230]
# Generator_loss:3.2441
# L1_loss:0.1211
# Discriminator_loss:0.4341
#
# EPOCH[98] - STEP[240]
# Generator_loss:0.8764
# L1_loss:0.1122
# Discriminator_loss:0.7720
#
# EPOCH[98] - STEP[250]
# Generator_loss:3.1203
# L1_loss:0.1113
# Discriminator_loss:0.2224
#
# EPOCH[99] - STEP[10]
# Generator_loss:5.4855
# L1_loss:0.1903
# Discriminator_loss:0.0800
#
# EPOCH[99] - STEP[20]
# Generator_loss:3.0405
# L1_loss:0.1163
# Discriminator_loss:0.7965
#
# EPOCH[99] - STEP[30]
# Generator_loss:2.3011
# L1_loss:0.1410
# Discriminator_loss:0.2759
#
# EPOCH[99] - STEP[40]
# Generator_loss:3.0491
# L1_loss:0.1420
# Discriminator_loss:0.3419
#
# EPOCH[99] - STEP[50]
# Generator_loss:0.6864
# L1_loss:0.1810
# Discriminator_loss:1.0521
#
# EPOCH[99] - STEP[60]
# Generator_loss:2.5821
# L1_loss:0.1239
# Discriminator_loss:0.1866
#
# EPOCH[99] - STEP[70]
# Generator_loss:1.3962
# L1_loss:0.1160
# Discriminator_loss:0.7894
#
# EPOCH[99] - STEP[80]
# Generator_loss:3.1390
# L1_loss:0.1210
# Discriminator_loss:0.1058
#
# EPOCH[99] - STEP[90]
# Generator_loss:2.0996
# L1_loss:0.1141
# Discriminator_loss:0.5735
#
# EPOCH[99] - STEP[100]
# Generator_loss:0.4898
# L1_loss:0.0999
# Discriminator_loss:1.4781
#
# EPOCH[99] - STEP[110]
# Generator_loss:5.6889
# L1_loss:0.1073
# Discriminator_loss:0.5509
#
# EPOCH[99] - STEP[120]
# Generator_loss:5.2260
# L1_loss:0.1446
# Discriminator_loss:0.0555
#
# EPOCH[99] - STEP[130]
# Generator_loss:0.3316
# L1_loss:0.1372
# Discriminator_loss:2.2138
#
# EPOCH[99] - STEP[140]
# Generator_loss:4.3947
# L1_loss:0.1593
# Discriminator_loss:0.3485
# EPOCH[99] - STEP[150]
# Generator_loss:3.4414
# L1_loss:0.1276
# Discriminator_loss:0.0727
#
# EPOCH[99] - STEP[160]
# Generator_loss:2.8320
# L1_loss:0.1291
# Discriminator_loss:0.1834
#
# EPOCH[99] - STEP[170]
# Generator_loss:3.8632
# L1_loss:0.1424
# Discriminator_loss:0.0518
#
# EPOCH[99] - STEP[180]
# Generator_loss:3.7756
# L1_loss:0.1405
# Discriminator_loss:0.1756
#
# EPOCH[99] - STEP[190]
# Generator_loss:6.1025
# L1_loss:0.1520
# Discriminator_loss:0.1571
#
# EPOCH[99] - STEP[200]
# Generator_loss:3.0319
# L1_loss:0.1092
# Discriminator_loss:0.4602
#
# EPOCH[99] - STEP[210]
# Generator_loss:2.1127
# L1_loss:0.1218
# Discriminator_loss:0.2585
#
# EPOCH[99] - STEP[220]
# Generator_loss:3.9444
# L1_loss:0.1207
# Discriminator_loss:0.3576
#
# EPOCH[99] - STEP[230]
# Generator_loss:4.0702
# L1_loss:0.1614
# Discriminator_loss:0.0529
#
# EPOCH[99] - STEP[240]
# Generator_loss:3.1726
# L1_loss:0.1617
# Discriminator_loss:0.1841
#
# EPOCH[99] - STEP[250]
# Generator_loss:2.7933
# L1_loss:0.1604
# Discriminator_loss:0.2852
#
# EPOCH[100] - STEP[10]
# Generator_loss:1.9326
# L1_loss:0.1198
# Discriminator_loss:0.5688
#
# EPOCH[100] - STEP[20]
# Generator_loss:5.0363
# L1_loss:0.1124
# Discriminator_loss:1.5420
#
# EPOCH[100] - STEP[30]
# Generator_loss:3.5525
# L1_loss:0.1169
# Discriminator_loss:1.1886
#
# EPOCH[100] - STEP[40]
# Generator_loss:4.8086
# L1_loss:0.1227
# Discriminator_loss:0.1579
#
# EPOCH[100] - STEP[50]
# Generator_loss:2.9825
# L1_loss:0.1428
# Discriminator_loss:0.1716
#
# EPOCH[100] - STEP[60]
# Generator_loss:3.7463
# L1_loss:0.1332
# Discriminator_loss:0.1256
#
# EPOCH[100] - STEP[70]
# Generator_loss:2.6190
# L1_loss:0.1404
# Discriminator_loss:0.1644
#
# EPOCH[100] - STEP[80]
# Generator_loss:3.6811
# L1_loss:0.1111
# Discriminator_loss:0.0479
#
# EPOCH[100] - STEP[90]
# Generator_loss:2.4696
# L1_loss:0.1190
# Discriminator_loss:0.4288
#
# EPOCH[100] - STEP[100]
# Generator_loss:2.4573
# L1_loss:0.1262
# Discriminator_loss:0.2089
#
# EPOCH[100] - STEP[110]
# Generator_loss:1.8316
# L1_loss:0.1312
# Discriminator_loss:0.4310
#
# EPOCH[100] - STEP[120]
# Generator_loss:3.7925
# L1_loss:0.1219
# Discriminator_loss:0.0904
#
# EPOCH[100] - STEP[130]
# Generator_loss:2.8056
# L1_loss:0.1507
# Discriminator_loss:0.1221
#
# EPOCH[100] - STEP[140]
# Generator_loss:3.4441
# L1_loss:0.1224
# Discriminator_loss:0.3056
#
# EPOCH[100] - STEP[150]
# Generator_loss:2.9008
# L1_loss:0.1215
# Discriminator_loss:0.1958
#
# EPOCH[100] - STEP[160]
# Generator_loss:5.8609
# L1_loss:0.1542
# Discriminator_loss:0.0162
#
# EPOCH[100] - STEP[170]
# Generator_loss:3.2635
# L1_loss:0.1034
# Discriminator_loss:0.9113
#
# EPOCH[100] - STEP[180]
# Generator_loss:1.9309
# L1_loss:0.1140
# Discriminator_loss:0.3306
#
# EPOCH[100] - STEP[190]
# Generator_loss:5.2635
# L1_loss:0.1138
# Discriminator_loss:0.3717
#
# EPOCH[100] - STEP[200]
# Generator_loss:3.9037
# L1_loss:0.1306
# Discriminator_loss:0.3615
#
# EPOCH[100] - STEP[210]
# Generator_loss:2.3966
# L1_loss:0.1821
# Discriminator_loss:0.2054
#
# EPOCH[100] - STEP[220]
# Generator_loss:2.7670
# L1_loss:0.1229
# Discriminator_loss:0.4425
#
# EPOCH[100] - STEP[230]
# Generator_loss:3.3847
# L1_loss:0.1269
# Discriminator_loss:0.4197
#
# EPOCH[100] - STEP[240]
# Generator_loss:6.1411
# L1_loss:0.1659
# Discriminator_loss:2.6924
#
# EPOCH[100] - STEP[250]
# Generator_loss:0.3758
# L1_loss:0.1086
# Discriminator_loss:1.8870

# %% [markdown]
# ### 3. 모델 학습 후, 학습된 Generator를 이용해 테스트합니다. 테스트 데이터는 다운받았던 "val" 폴더 내 이미지를 사용해주세요.

# %%
test_ind = 1
data_path = os.getenv('HOME')+'/aiffel/conditional_generation/cityscapes/val/'

f = data_path + os.listdir(data_path)[test_ind]
sketch, colored = load_img(f)

pred = generator(tf.expand_dims(sketch, 0))
pred = denormalize(pred)

plt.figure(figsize=(20,10))
plt.subplot(1,3,1); plt.imshow(denormalize(sketch))
plt.subplot(1,3,2); plt.imshow(pred[0])
plt.subplot(1,3,3); plt.imshow(denormalize(colored))

# %% [markdown]
# epoch == 10
# ![image.png](attachment:image.png)

# %% [markdown]
# epoch == 20
#
# ![image.png](attachment:image.png)

# %% [markdown]
# epoch ==100
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 총평
#
# * LMS를 통해서 GAN, DCGAN, CGAN을 배워 볼 수 있었다. 이번 CGAN의 경우, 단순한 원리를 추가한 구조인데, 조건을 주어 제어가 가능하고 다양한 활용이 가능해 졌다는 것과 논문이나 기타 자료를 통해 살펴보면서 이런한 차이를 보인다는 것에 놀라웠다. 기본을 정확히 아는것이 중요하구나 라는 생각을 했다. 새로운 모델을 창조하는것이 무에서 유가 아닌, 이런 단순한 시도에서 나온다는 것이 고무적이었다. 이 모델이 2014년에 나온것이라니, 이후의 다양한  GAN의 발전 된 모델을 배울 것이 기대된다.
#
# * 10번 이상의 학습을 하는것이 루브릭이었으며, 학습시간이 많이 소요되지 않아 100회까지 차이를 비교해 보았다. 성능은 나아졌으나, 100회 정도로는 학습량이 부족해 보인다.
#
# * U-Net generator, discriminator 모델 구현이 완료되어 train_step이 안정적으로 진행됨을 확인하였다.
